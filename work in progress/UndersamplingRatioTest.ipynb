# %%
# Import packages
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from collections import Counter
from parse import preprocess

# %%
# Function to show classification report for Cross Validation
def classification_report_with_accuracy_score(y_true, y_pred):
    print(classification_report(y_true, y_pred)) # print classification report
    return accuracy_score(y_true, y_pred) # return accuracy score

# %%
# Pre-parse the dataset
data = preprocess("rawfile_blood.csv")
# Out:
# ####################################################################
# Number of Rows of Dataframe:
# 1123
# Number of Columns of Dataframe:
# 59
#
# ####################################################################
# Threshold for number of NULLs in a column: 0.1095
# Number of Columns before Parsing for Too Many NULLs in a column:
# 59
# Number of Columns after Parsing for Too Many NULLs in a column:
# 51
#
# Columns Removed:
# B1_b5
# B4_a1
# B4_a3
# B4_a4
# B4_a6
# B4_b1
# B4_b3
# B5_a1
#
# ####################################################################
# Number of Rows before Parsing NULLs in data:
# 1123
# Number of Rows after Parsing NULLs in data:
# 1007
#
# ####################################################################
# Number of Columns after dropping A1_2, B1_b4, B2_c3, B4_b2 for inconsistent data types:
# 47

# %%
# Test the undersampling ratio to find best accuracy for Random Forest Classifier
# Define undersample strategy

val = 339

x_axis = []
y_axis1 = []
y_axis2 = []

while (val > 9):
    c = data['condition'].value_counts()
    condition = c.index
    
    for i in range(len(condition)):
        data['condition'].replace(condition[i], i, inplace = True)
    
    y = data['condition']
    
    features = ['A1_1', 'A2_1', 'A3_1', 'B1_a', 'B1_a1', 'B1_a2',
       'B1_a3', 'B1_a4', 'B1_a5', 'B1_a6', 'B1_b', 'B1_b1', 'B1_b2', 'B1_b3',
       'B1_c', 'B1_d', 'B2_a1', 'B2_a2', 'B2_a3', 'B2_a4', 'B2_a5', 'B2_b1',
       'B2_b2', 'B2_b3', 'B2_c1', 'B2_c2', 'B2_c4', 'B2_c5', 'B2_c6', 'B2_c7',
       'B2_d1', 'B2_d2', 'B2_d3', 'B2_d4', 'B2_d5', 'B2_d6', 'B2_d7', 'B2_d8',
       'B2_d9', 'B3', 'B4_a2', 'B4_a5', 'B5_a2', 'B5_a3', 'B6']
    
    X_old = data[features]
    
    X = X_old

    if (val < 77):
        sampling_strategy = {0: val, 1: val, 2: val, 3: val, 4: val, 5: 7}
    elif (val < 134):
        sampling_strategy = {0: val, 1: val, 2: val, 3: val, 4: 76, 5: 7}
    elif (val < 222):
        sampling_strategy = {0: val, 1: val, 2: val, 3: 133, 4: 76, 5: 7}
    elif (val < 232):
        sampling_strategy = {0: val, 1: val, 2: 221, 3: 133, 4: 76, 5: 7}
    elif (val < 340):
        sampling_strategy = {0: val, 1: 231, 2: 221, 3: 133, 4: 76, 5: 7}
    
    undersample = RandomUnderSampler(sampling_strategy=sampling_strategy)

    X, y = undersample.fit_resample(X, y)
    
    # Transform the dataset using SMOTE
    oversample = SMOTE()
    X, y = oversample.fit_resample(X, y)
    
    # Random Forest Classifier
    rfc_model = RandomForestClassifier()
    rfc_model.fit(X, y)
    scores = cross_val_score(rfc_model, X, y, cv=10)
    print("==> Majority Class Samples:", val)
    print("Random Forest Classifier: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
    
    # Append into lists to plot graph
    x_axis.append(val)
    y_axis1.append(scores.mean())
    y_axis2.append(scores.std())
    
    val -= 1
# Out:
# ==> Majority Class Samples: 339
# Random Forest Classifier: 0.76 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 338
# Random Forest Classifier: 0.78 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 337
# Random Forest Classifier: 0.77 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 336
# Random Forest Classifier: 0.76 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 335
# Random Forest Classifier: 0.76 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 334
# Random Forest Classifier: 0.76 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 333
# Random Forest Classifier: 0.77 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 332
# Random Forest Classifier: 0.77 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 331
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 330
# Random Forest Classifier: 0.76 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 329
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 328
# Random Forest Classifier: 0.76 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 327
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 326
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 325
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 324
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 323
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 322
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 321
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 320
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 319
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 318
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 317
# Random Forest Classifier: 0.73 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 316
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 315
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 314
# Random Forest Classifier: 0.73 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 313
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 312
# Random Forest Classifier: 0.73 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 311
# Random Forest Classifier: 0.75 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 310
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 309
# Random Forest Classifier: 0.74 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 308
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 307
# Random Forest Classifier: 0.73 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 306
# Random Forest Classifier: 0.71 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 305
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 304
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.10
# ==> Majority Class Samples: 303
# Random Forest Classifier: 0.73 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 302
# Random Forest Classifier: 0.71 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 301
# Random Forest Classifier: 0.73 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 300
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 299
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 298
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 297
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 296
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 295
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 294
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 293
# Random Forest Classifier: 0.72 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 292
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 291
# Random Forest Classifier: 0.71 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 290
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 289
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 288
# Random Forest Classifier: 0.71 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 287
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 286
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 285
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 284
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 283
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 282
# Random Forest Classifier: 0.69 accuracy with a standard deviation of 0.10
# ==> Majority Class Samples: 281
# Random Forest Classifier: 0.69 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 280
# Random Forest Classifier: 0.71 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 279
# Random Forest Classifier: 0.69 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 278
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 277
# Random Forest Classifier: 0.69 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 276
# Random Forest Classifier: 0.69 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 275
# Random Forest Classifier: 0.68 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 274
# Random Forest Classifier: 0.70 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 273
# Random Forest Classifier: 0.69 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 272
# Random Forest Classifier: 0.68 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 271
# Random Forest Classifier: 0.68 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 270
# Random Forest Classifier: 0.66 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 269
# Random Forest Classifier: 0.68 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 268
# Random Forest Classifier: 0.67 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 267
# Random Forest Classifier: 0.68 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 266
# Random Forest Classifier: 0.67 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 265
# Random Forest Classifier: 0.67 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 264
# Random Forest Classifier: 0.68 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples:
accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 179
# Random Forest Classifier: 0.55 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 178
# Random Forest Classifier: 0.56 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 177
# Random Forest Classifier: 0.55 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 176
# Random Forest Classifier: 0.56 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 175
# Random Forest Classifier: 0.53 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 174
# Random Forest Classifier: 0.54 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 173
# Random Forest Classifier: 0.52 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 172
# Random Forest Classifier: 0.56 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 171
# Random Forest Classifier: 0.56 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 170
# Random Forest Classifier: 0.53 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 169
# Random Forest Classifier: 0.56 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 168
# Random Forest Classifier: 0.54 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 167
# Random Forest Classifier: 0.53 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 166
# Random Forest Classifier: 0.54 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 165
# Random Forest Classifier: 0.54 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 164
# Random Forest Classifier: 0.53 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 163
# Random Forest Classifier: 0.53 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 162
# Random Forest Classifier: 0.49 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 161
# Random Forest Classifier: 0.52 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 160
# Random Forest Classifier: 0.54 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 159
# Random Forest Classifier: 0.51 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 158
# Random Forest Classifier: 0.53 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 157
# Random Forest Classifier: 0.51 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 156
# Random Forest Classifier: 0.51 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 155
# Random Forest Classifier: 0.53 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 154
# Random Forest Classifier: 0.48 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 153
# Random Forest Classifier: 0.50 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 152
# Random Forest Classifier: 0.52 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 151
# Random Forest Classifier: 0.48 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 150
# Random Forest Classifier: 0.50 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 149
# Random Forest Classifier: 0.50 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 148
# Random Forest Classifier: 0.51 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 147
# Random Forest Classifier: 0.50 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 146
# Random Forest Classifier: 0.50 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 145
# Random Forest Classifier: 0.52 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 144
# Random Forest Classifier: 0.48 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 143
# Random Forest Classifier: 0.49 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 142
# Random Forest Classifier: 0.50 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 141
# Random Forest Classifier: 0.51 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 140
# Random Forest Classifier: 0.49 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 139
# Random Forest Classifier: 0.49 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 138
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 137
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 136
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.03
# ==> Majority Class Samples: 135
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 134
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 133
# Random Forest Classifier: 0.48 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 132
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 131
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 130
# Random Forest Classifier: 0.45 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 129
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 128
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 127
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 126
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.03
# ==> Majority Class Samples: 125
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 124
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 123
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 122
# Random Forest Classifier: 0.44 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 121
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 120
# Random Forest Classifier: 0.45 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 119
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 118
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 117
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 116
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.03
# ==> Majority Class Samples: 115
# Random Forest Classifier: 0.45 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 114
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 113
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 112
# Random Forest Classifier: 0.43 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 111
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 110
# Random Forest Classifier: 0.45 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 109
# Random Forest Classifier: 0.44 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 108
# Random Forest Classifier: 0.43 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 107
# Random Forest Classifier: 0.45 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 106
# Random Forest Classifier: 0.44 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 105
# Random Forest Classifier: 0.42 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 104
# Random Forest Classifier: 0.43 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 103
# Random Forest Classifier: 0.45 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 102
# Random Forest Classifier: 0.43 accuracy with a standard deviation of 0.03
# ==> Majority Class Samples: 101
# Random Forest Classifier: 0.47 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 100
# Random Forest Classifier: 0.45 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 99
# Random Forest Classifier: 0.43 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 98
# Random Forest Classifier: 0.43 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 97
# Random Forest Classifier: 0.41 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 96
# Random Forest Classifier: 0.41 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 95
# Random Forest Classifier: 0.42 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 94
# Random Forest Classifier: 0.41 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 93
# Random Forest Classifier: 0.46 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 92
# Random Forest Classifier: 0.41 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 91
# Random Forest Classifier: 0.40 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 90
# Random Forest Classifier: 0.43 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 89
# Random Forest Classifier: 0.43 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 88
# Random Forest Classifier: 0.39 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 87
# Random Forest Classifier: 0.39 accuracy with a standard deviation of 0.03
# ==> Majority Class Samples: 86
# Random Forest Classifier: 0.41 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 85
# Random Forest Classifier: 0.39 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 84
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 83
# Random Forest Classifier: 0.41 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 82
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 81
# Random Forest Classifier: 0.40 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 80
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 79
# Random Forest Classifier: 0.37 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 78
# Random Forest Classifier: 0.35 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 77
# Random Forest Classifier: 0.40 accuracy with a standard deviation of 0.03
# ==> Majority Class Samples: 76
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 75
# Random Forest Classifier: 0.37 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 74
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 73
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 72
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 71
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 70
# Random Forest Classifier: 0.37 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 69
# Random Forest Classifier: 0.37 accuracy with a standard deviation of 0.03
# ==> Majority Class Samples: 68
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 67
# Random Forest Classifier: 0.42 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 66
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 65
# Random Forest Classifier: 0.40 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 64
# Random Forest Classifier: 0.37 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 63
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 62
# Random Forest Classifier: 0.40 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 61
# Random Forest Classifier: 0.33 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 60
# Random Forest Classifier: 0.40 accuracy with a standard deviation of 0.10
# ==> Majority Class Samples: 59
# Random Forest Classifier: 0.39 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 58
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 57
# Random Forest Classifier: 0.40 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 56
# Random Forest Classifier: 0.39 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 55
# Random Forest Classifier: 0.32 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 54
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.04
# ==> Majority Class Samples: 53
# Random Forest Classifier: 0.39 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 52
# Random Forest Classifier: 0.34 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 51
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 50
# Random Forest Classifier: 0.34 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 49
# Random Forest Classifier: 0.32 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 48
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 47
# Random Forest Classifier: 0.34 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 46
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 45
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 44
# Random Forest Classifier: 0.34 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 43
# Random Forest Classifier: 0.33 accuracy with a standard deviation of 0.05
# ==> Majority Class Samples: 42
# Random Forest Classifier: 0.35 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 41
# Random Forest Classifier: 0.31 accuracy with a standard deviation of 0.06
# ==> Majority Class Samples: 40
# Random Forest Classifier: 0.33 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 39
# Random Forest Classifier: 0.37 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 38
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 37
# Random Forest Classifier: 0.32 accuracy with a standard deviation of 0.10
# ==> Majority Class Samples: 36
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 35
# Random Forest Classifier: 0.33 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 34
# Random Forest Classifier: 0.32 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 33
# Random Forest Classifier: 0.41 accuracy with a standard deviation of 0.10
# ==> Majority Class Samples: 32
# Random Forest Classifier: 0.33 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 31
# Random Forest Classifier: 0.35 accuracy with a standard deviation of 0.08
# ==> Majority Class Samples: 30
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.12
# ==> Majority Class Samples: 29
# Random Forest Classifier: 0.39 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 28
# Random Forest Classifier: 0.34 accuracy with a standard deviation of 0.10
# ==> Majority Class Samples: 27
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 26
# Random Forest Classifier: 0.38 accuracy with a standard deviation of 0.11
# ==> Majority Class Samples: 25
# Random Forest Classifier: 0.33 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 24
# Random Forest Classifier: 0.42 accuracy with a standard deviation of 0.13
# ==> Majority Class Samples: 23
# Random Forest Classifier: 0.35 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 22
# Random Forest Classifier: 0.29 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 21
# Random Forest Classifier: 0.36 accuracy with a standard deviation of 0.12
# ==> Majority Class Samples: 20
# Random Forest Classifier: 0.29 accuracy with a standard deviation of 0.09
# ==> Majority Class Samples: 19
# Random Forest Classifier: 0.32 accuracy with a standard deviation of 0.12
# ==> Majority Class Samples: 18
# Random Forest Classifier: 0.33 accuracy with a standard deviation of 0.07
# ==> Majority Class Samples: 17
# Random Forest Classifier: 0.27 accuracy with a standard deviation of 0.12
# ==> Majority Class Samples: 16
# Random Forest Classifier: 0.35 accuracy with a standard deviation of 0.14
# ==> Majority Class Samples: 15
# Random Forest Classifier: 0.20 accuracy with a standard deviation of 0.12
# ==> Majority Class Samples: 14
# Random Forest Classifier: 0.30 accuracy with a standard deviation of 0.14
# ==> Majority Class Samples: 13
# Random Forest Classifier: 0.23 accuracy with a standard deviation of 0.16
# ==> Majority Class Samples: 12
# Random Forest Classifier: 0.29 accuracy with a standard deviation of 0.16
# ==> Majority Class Samples: 11
# Random Forest Classifier: 0.28 accuracy with a standard deviation of 0.13
# ==> Majority Class Samples: 10
# Random Forest Classifier: 0.27 accuracy with a standard deviation of 0.15

# %%
import matplotlib.pyplot as plt

plt.plot(x_axis, y_axis1)
plt.xlabel("No. of Majority Class Samples")
plt.ylabel("RFC Cross Validation Accuracy (k=10)")
plt.title("RFC CV Accuracy vs Majority Class Samples")
# Out:
# Text(0.5, 1.0, 'RFC CV Accuracy vs Majority Class Samples')

# %%
plt.plot(x_axis, y_axis2)
plt.xlabel("No. of Majority Class Samples")
plt.ylabel("RFC Cross Validation Standard Deviation (k=10)")
plt.title("RFC CV Std Dv vs Majority Class Samples")
# Out:
# Text(0.5, 1.0, 'RFC CV Std Dv vs Majority Class Samples')

# %%
# Test the undersampling ratio to find best accuracy (using Holdout Method) for Random Forest Classifier
# Define undersample strategy

val = 339

x_axis = []
y_axis = []

while (val > 9):
    c = data['condition'].value_counts()
    condition = c.index
    
    for i in range(len(condition)):
        data['condition'].replace(condition[i], i, inplace = True)
    
    y = data['condition']
    
    features = ['A1_1', 'A2_1', 'A3_1', 'B1_a', 'B1_a1', 'B1_a2',
       'B1_a3', 'B1_a4', 'B1_a5', 'B1_a6', 'B1_b', 'B1_b1', 'B1_b2', 'B1_b3',
       'B1_c', 'B1_d', 'B2_a1', 'B2_a2', 'B2_a3', 'B2_a4', 'B2_a5', 'B2_b1',
       'B2_b2', 'B2_b3', 'B2_c1', 'B2_c2', 'B2_c4', 'B2_c5', 'B2_c6', 'B2_c7',
       'B2_d1', 'B2_d2', 'B2_d3', 'B2_d4', 'B2_d5', 'B2_d6', 'B2_d7', 'B2_d8',
       'B2_d9', 'B3', 'B4_a2', 'B4_a5', 'B5_a2', 'B5_a3', 'B6']
    
    X_old = data[features]
    
    X = X_old

    if (val < 77):
        sampling_strategy = {0: val, 1: val, 2: val, 3: val, 4: val, 5: 7}
    elif (val < 134):
        sampling_strategy = {0: val, 1: val, 2: val, 3: val, 4: 76, 5: 7}
    elif (val < 222):
        sampling_strategy = {0: val, 1: val, 2: val, 3: 133, 4: 76, 5: 7}
    elif (val < 232):
        sampling_strategy = {0: val, 1: val, 2: 221, 3: 133, 4: 76, 5: 7}
    elif (val < 340):
        sampling_strategy = {0: val, 1: 231, 2: 221, 3: 133, 4: 76, 5: 7}
    
    undersample = RandomUnderSampler(sampling_strategy=sampling_strategy)

    X, y = undersample.fit_resample(X, y)
    
    # Transform the dataset using SMOTE
    oversample = SMOTE()
    X, y = oversample.fit_resample(X, y)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)
    
   # Random Forest Classifier
    rfc_model = RandomForestClassifier()
    rfc_model.fit(X_train, y_train)
    print("==> Majority Class Samples:", val)
    print("Random Forest Classifier:", rfc_model.score(X_test, y_test).round(3))
    
    # Append into lists to plot graph
    x_axis.append(val)
    y_axis.append(rfc_model.score(X_test, y_test).round(3))
    
    val -= 1
# Out:
# ==> Majority Class Samples: 339
# Random Forest Classifier: 0.752
# ==> Majority Class Samples: 338
# Random Forest Classifier: 0.773
# ==> Majority Class Samples: 337
# Random Forest Classifier: 0.753
# ==> Majority Class Samples: 336
# Random Forest Classifier: 0.748
# ==> Majority Class Samples: 335
# Random Forest Classifier: 0.726
# ==> Majority Class Samples: 334
# Random Forest Classifier: 0.781
# ==> Majority Class Samples: 333
# Random Forest Classifier: 0.698
# ==> Majority Class Samples: 332
# Random Forest Classifier: 0.752
# ==> Majority Class Samples: 331
# Random Forest Classifier: 0.764
# ==> Majority Class Samples: 330
# Random Forest Classifier: 0.75
# ==> Majority Class Samples: 329
# Random Forest Classifier: 0.722
# ==> Majority Class Samples: 328
# Random Forest Classifier: 0.726
# ==> Majority Class Samples: 327
# Random Forest Classifier: 0.768
# ==> Majority Class Samples: 326
# Random Forest Classifier: 0.714
# ==> Majority Class Samples: 325
# Random Forest Classifier: 0.695
# ==> Majority Class Samples: 324
# Random Forest Classifier: 0.735
# ==> Majority Class Samples: 323
# Random Forest Classifier: 0.74
# ==> Majority Class Samples: 322
# Random Forest Classifier: 0.713
# ==> Majority Class Samples: 321
# Random Forest Classifier: 0.684
# ==> Majority Class Samples: 320
# Random Forest Classifier: 0.768
# ==> Majority Class Samples: 319
# Random Forest Classifier: 0.721
# ==> Majority Class Samples: 318
# Random Forest Classifier: 0.696
# ==> Majority Class Samples: 317
# Random Forest Classifier: 0.69
# ==> Majority Class Samples: 316
# Random Forest Classifier: 0.689
# ==> Majority Class Samples: 315
# Random Forest Classifier: 0.704
# ==> Majority Class Samples: 314
# Random Forest Classifier: 0.711
# ==> Majority Class Samples: 313
# Random Forest Classifier: 0.713
# ==> Majority Class Samples: 312
# Random Forest Classifier: 0.699
# ==> Majority Class Samples: 311
# Random Forest Classifier: 0.706
# ==> Majority Class Samples: 310
# Random Forest Classifier: 0.699
# ==> Majority Class Samples: 309
# Random Forest Classifier: 0.687
# ==> Majority Class Samples: 308
# Random Forest Classifier: 0.705
# ==> Majority Class Samples: 307
# Random Forest Classifier: 0.691
# ==> Majority Class Samples: 306
# Random Forest Classifier: 0.674
# ==> Majority Class Samples: 305
# Random Forest Classifier: 0.689
# ==> Majority Class Samples: 304
# Random Forest Classifier: 0.679
# ==> Majority Class Samples: 303
# Random Forest Classifier: 0.698
# ==> Majority Class Samples: 302
# Random Forest Classifier: 0.456
# ==> Majority Class Samples: 103
# Random Forest Classifier: 0.452
# ==> Majority Class Samples: 102
# Random Forest Classifier: 0.455
# ==> Majority Class Samples: 101
# Random Forest Classifier: 0.385
# ==> Majority Class Samples: 100
# Random Forest Classifier: 0.442
# ==> Majority Class Samples: 99
# Random Forest Classifier: 0.454
# ==> Majority Class Samples: 98
# Random Forest Classifier: 0.39
# ==> Majority Class Samples: 97
# Random Forest Classifier: 0.453
# ==> Majority Class Samples: 96
# Random Forest Classifier: 0.474
# ==> Majority Class Samples: 95
# Random Forest Classifier: 0.386
# ==> Majority Class Samples: 94
# Random Forest Classifier: 0.363
# ==> Majority Class Samples: 93
# Random Forest Classifier: 0.339
# ==> Majority Class Samples: 92
# Random Forest Classifier: 0.378
# ==> Majority Class Samples: 91
# Random Forest Classifier: 0.4
# ==> Majority Class Samples: 90
# Random Forest Classifier: 0.426
# ==> Majority Class Samples: 89
# Random Forest Classifier: 0.449
# ==> Majority Class Samples: 88
# Random Forest Classifier: 0.425
# ==> Majority Class Samples: 87
# Random Forest Classifier: 0.4
# ==> Majority Class Samples: 86
# Random Forest Classifier: 0.365
# ==> Majority Class Samples: 85
# Random Forest Classifier: 0.441
# ==> Majority Class Samples: 84
# Random Forest Classifier: 0.426
# ==> Majority Class Samples: 83
# Random Forest Classifier: 0.36
# ==> Majority Class Samples: 82
# Random Forest Classifier: 0.455
# ==> Majority Class Samples: 81
# Random Forest Classifier: 0.398
# ==> Majority Class Samples: 80
# Random Forest Classifier: 0.427
# ==> Majority Class Samples: 79
# Random Forest Classifier: 0.4
# ==> Majority Class Samples: 78
# Random Forest Classifier: 0.404
# ==> Majority Class Samples: 77
# Random Forest Classifier: 0.366
# ==> Majority Class Samples: 76
# Random Forest Classifier: 0.391
# ==> Majority Class Samples: 75
# Random Forest Classifier: 0.422
# ==> Majority Class Samples: 74
# Random Forest Classifier: 0.348
# ==> Majority Class Samples: 73
# Random Forest Classifier: 0.352
# ==> Majority Class Samples: 72
# Random Forest Classifier: 0.299
# ==> Majority Class Samples: 71
# Random Forest Classifier: 0.395
# ==> Majority Class Samples: 70
# Random Forest Classifier: 0.405
# ==> Majority Class Samples: 69
# Random Forest Classifier: 0.458
# ==> Majority Class Samples: 68
# Random Forest Classifier: 0.415
# ==> Majority Class Samples: 67
# Random Forest Classifier: 0.346
# ==> Majority Class Samples: 66
# Random Forest Classifier: 0.412
# ==> Majority Class Samples: 65
# Random Forest Classifier: 0.321
# ==> Majority Class Samples: 64
# Random Forest Classifier: 0.364
# ==> Majority Class Samples: 63
# Random Forest Classifier: 0.408
# ==> Majority Class Samples: 62
# Random Forest Classifier: 0.413
# ==> Majority Class Samples: 61
# Random Forest Classifier: 0.311
# ==> Majority Class Samples: 60
# Random Forest Classifier: 0.361
# ==> Majority Class Samples: 59
# Random Forest Classifier: 0.38
# ==> Majority Class Samples: 58
# Random Forest Classifier: 0.271
# ==> Majority Class Samples: 57
# Random Forest Classifier: 0.377
# ==> Majority Class Samples: 56
# Random Forest Classifier: 0.397
# ==> Majority Class Samples: 55
# Random Forest Classifier: 0.348
# ==> Majority Class Samples: 54
# Random Forest Classifier: 0.4
# ==> Majority Class Samples: 53
# Random Forest Classifier: 0.312
# ==> Majority Class Samples: 52
# Random Forest Classifier: 0.381
# ==> Majority Class Samples: 51
# Random Forest Classifier: 0.452
# ==> Majority Class Samples: 50
# Random Forest Classifier: 0.4
# ==> Majority Class Samples: 49
# Random Forest Classifier: 0.356
# ==> Majority Class Samples: 48
# Random Forest Classifier: 0.397
# ==> Majority Class Samples: 47
# Random Forest Classifier: 0.386
# ==> Majority Class Samples: 46
# Random Forest Classifier: 0.321
# ==> Majority Class Samples: 45
# Random Forest Classifier: 0.37
# ==> Majority Class Samples: 44
# Random Forest Classifier: 0.377
# ==> Majority Class Samples: 43
# Random Forest Classifier: 0.404
# ==> Majority Class Samples: 42
# Random Forest Classifier: 0.314
# ==> Majority Class Samples: 41
# Random Forest Classifier: 0.48
# ==> Majority Class Samples: 40
# Random Forest Classifier: 0.396
# ==> Majority Class Samples: 39
# Random Forest Classifier: 0.426
# ==> Majority Class Samples: 38
# Random Forest Classifier: 0.391
# ==> Majority Class Samples: 37
# Random Forest Classifier: 0.244
# ==> Majority Class Samples: 36
# Random Forest Classifier: 0.341
# ==> Majority Class Samples: 35
# Random Forest Classifier: 0.262
# ==> Majority Class Samples: 34
# Random Forest Classifier: 0.512
# ==> Majority Class Samples: 33
# Random Forest Classifier: 0.225
# ==> Majority Class Samples: 32
# Random Forest Classifier: 0.385
# ==> Majority Class Samples: 31
# Random Forest Classifier: 0.316
# ==> Majority Class Samples: 30
# Random Forest Classifier: 0.278
# ==> Majority Class Samples: 29
# Random Forest Classifier: 0.286
# ==> Majority Class Samples: 28
# Random Forest Classifier: 0.353
# ==> Majority Class Samples: 27
# Random Forest Classifier: 0.212
# ==> Majority Class Samples: 26
# Random Forest Classifier: 0.375
# ==> Majority Class Samples: 25
# Random Forest Classifier: 0.367
# ==> Majority Class Samples: 24
# Random Forest Classifier: 0.31
# ==> Majority Class Samples: 23
# Random Forest Classifier: 0.286
# ==> Majority Class Samples: 22
# Random Forest Classifier: 0.185
# ==> Majority Class Samples: 21
# Random Forest Classifier: 0.577
# ==> Majority Class Samples: 20
# Random Forest Classifier: 0.292
# ==> Majority Class Samples: 19
# Random Forest Classifier: 0.304
# ==> Majority Class Samples: 18
# Random Forest Classifier: 0.273
# ==> Majority Class Samples: 17
# Random Forest Classifier: 0.333
# ==> Majority Class Samples: 16
# Random Forest Classifier: 0.3
# ==> Majority Class Samples: 15
# Random Forest Classifier: 0.167
# ==> Majority Class Samples: 14
# Random Forest Classifier: 0.294
# ==> Majority Class Samples: 13
# Random Forest Classifier: 0.125
# ==> Majority Class Samples: 12
# Random Forest Classifier: 0.067
# ==> Majority Class Samples: 11
# Random Forest Classifier: 0.214
# ==> Majority Class Samples: 10
# Random Forest Classifier: 0.167

# %%
plt.plot(x_axis, y_axis)
plt.xlabel("No. of Majority Class Samples")
plt.ylabel("RFC Holdout Method Accuracy (k=10)")
plt.title("RFC Holdout Accuracy vs Majority Class Samples")
# Out:
# Text(0.5, 1.0, 'RFC Holdout Accuracy vs Majority Class Samples')
