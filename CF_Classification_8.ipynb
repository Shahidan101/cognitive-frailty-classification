# %%
# Import packages
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import RFE
from collections import Counter
from robust_frailmci_parser import RobustFrailMCIpreprocess

# %%
# Function to show classification report for Cross Validation
def classification_report_with_accuracy_score(y_true, y_pred):
    print(classification_report(y_true, y_pred)) # print classification report
    return accuracy_score(y_true, y_pred) # return accuracy score

# %%
# Conduct High Correlation Filter

# Conduct mapping for Feature Names
featureName_mapping = {
    "A1_1" : "Vitamin B12 (pmol/L)",
    "A1_2" : "Serum Folate (nmol/L)",
    "A2_1" : "Serum Homocysteine (µmol/L)",
    "A3_1" : "25-hydroxy Vitamin D (nmol/L)",
    "B1_a" : "Haemoglobin (g/L)",
    "B1_a1" : "RBC (/L)",
    "B1_a2" : "PCV (L/L)",
    "B1_a3" : "MCV (fL)",
    "B1_a4" : "MCH (pg)",
    "B1_a5" : "MCHC (g/L)",
    "B1_a6" : "RDW (%)",
    "B1_b" : "White Cell Count (/L)",
    "B1_b1" : "Neutrophils (/L)",
    "B1_b2" : "Lymphocytes (/L)",
    "B1_b3" : "Monocytes (/L)",
    "B1_b4" : "Eosinophils (/L)",
    "B1_b5" : "Basophils (/L)",
    "B1_c" : "Platelets (/L)",
    "B1_d" : "Glucose (mmol/L)",
    "B2_a1" : "Total Cholesterol (mmol/L)",
    "B2_a2" : "Triglyceride (mmol/L)",
    "B2_a3" : "HDL Cholesterol (mmol/L)",
    "B2_a4" : "LDL Cholesterol (mmol/L)",
    "B2_a5" : "Total Cholesterol/HDL Ratio",
    "B2_b1" : "Sodium (mmol/L)",
    "B2_b2" : "Potassium (mmol/L)",
    "B2_b3" : "Chloride (mmol/L)",
    "B2_c1" : 'Urea (mmol/L)',
    "B2_c2" : "Creatinine (umol/L)",
    "B2_c3" : "eGFR (mL/min/1.73m2)",
    "B2_c4" : "Uric Acid (mmol/L)",
    "B2_c5" : "Calcium (mmol/L)",
    "B2_c6" : "Corrected Calcium (mmol/L)",
    "B2_c7" : "Phosphate (mmol/L)",
    "B2_d1" : "Total Protein (g/L)",
    "B2_d2" : "Albumin (g/L)",
    "B2_d3" : "Globulin (g/L)",
    "B2_d4" : "Albumin/Globulin ratio",
    "B2_d5" : "Alkaline Phosphatase (U/L)",
    "B2_d6" : "Total Bilirubin (µmol/L)",
    "B2_d7" : "GGT",
    "B2_d8" : "AST",
    "B2_d9" : "ALT",
    "B3" : "C-Reactive Protein",
    "B4_a1" : "Protein",
    "B4_a2" : "pH",
    "B4_a3" : "Glucose",
    "B4_a4" : "Ketones",
    "B4_a5" : "S.G.",
    "B4_a6" : "Blood",
    "B4_b1" : "Leucocytes (/L)",
    "B4_b2" : "Erythrocytes (/L)",
    "B4_b3" : "Epithelial Cells",
    "B5_a1" : "Free Thyroxine (FT4) (pmol/L)",
    "B5_a2" : "Thyroid Stimulating Hormone (mIU/L)",
    "B5_a3" : "Free Tri-iodothyronine (FT3) (pmol/L)",
    "B6" : "HbA1c"
}

# %%
# Test 4: Using New Dataset, 343 Robust with 76 Frail+MCI

# %%
# Pre-parse the dataset
data = RobustFrailMCIpreprocess("rawfile_robust_frailmci.csv")
# Out:
# robust       368
# frail_mci     86
# Name: condition, dtype: int64
#
# ####################################################################
# Number of Rows of Dataframe:
# 454
# Number of Columns of Dataframe:
# 59
#
# ####################################################################
# Threshold for number of NULLs in a column: 0.1095
# Number of Columns before Parsing for Too Many NULLs in a column:
# 59
# Number of Columns after Parsing for Too Many NULLs in a column:
# 51
#
# Columns Removed:
# B1_b5
# B4_a1
# B4_a3
# B4_a4
# B4_a6
# B4_b1
# B4_b3
# B5_a1
#
# ####################################################################
# Number of Columns after dropping B1_b4, B2_c3, B4_b2 for inconsistent data types:
# 48
#
# ####################################################################
# Number of Rows before Parsing NULLs in data:
# 454
# Number of Rows after Parsing NULLs in data:
# 419

# %%
# Taking only Frail+MCI and Robust classes

df1 = data[data.condition == 'frail_mci']
df1 = df1.reset_index(drop=True)

df2 = data[data.condition == 'robust']
df2 = df2.reset_index(drop=True)

data = pd.concat([df1, df2], ignore_index=True)

# %%
data.head()
# Out:
#       mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  ...  \
# 0  ME01378  frail_mci   241  13.0    20  33.5   150   5.25   0.46     87  ...
# 1  ME02832  frail_mci   444  43.8    16  87.0   134   4.65   0.40     85  ...
# 2  ME02909  frail_mci  1476  54.5    16  57.0   119   3.80   0.36     94  ...
# 3  ME02998  frail_mci   339  25.9    18  63.8   135   4.89   0.42     86  ...
# 4  ME03061  frail_mci   287  23.8    20  95.5   146   5.18   0.44     85  ...
#
#    B2_d6  B2_d7  B2_d8  B2_d9    B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 0     10     21     22     17   1.3    7.0  1.010   0.69    4.7  5.9
# 1     10     14     20     15  13.4    6.0  1.005   1.29    4.5  5.8
# 2     18     17     35     21   0.2    7.5  1.012   1.90    4.1  5.8
# 3     13     16     25     13  16.8    5.0  1.017   1.32    4.0  6.0
# 4     18     22     25     24   1.4    7.5  1.006   2.94    4.6  6.1
#
# [5 rows x 48 columns]

# %%
data.tail()
# Out:
#         mtag condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  \
# 414  MV00454    robust   220  24.6    19  67.5   138   4.66   0.42     91
# 415  MV00456    robust   334  20.1    18  51.0   139   4.63   0.42     91
# 416  MV00460    robust   418  54.4    17  61.0   122   4.18   0.38     90
# 417  MV00502    robust   393  38.2    18  43.1   136   4.57   0.43     94
# 418  MV00510    robust   371  23.2    24  55.9   127   4.41   0.40     90
#
#      ...  B2_d6  B2_d7  B2_d8  B2_d9   B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 414  ...     20     10     17      8  6.6    7.0  1.015   1.29    4.5  6.2
# 415  ...     16     22     35     40  1.0    6.0  1.015   1.88    3.9  5.6
# 416  ...     19     20     23     15  0.4    6.5  1.005   3.58    4.0  5.6
# 417  ...     13     11     22     23  0.7    7.0  1.009   0.92    4.1  6.0
# 418  ...     13     14     16     12  7.5    8.0  1.017   2.45    4.5  6.2
#
# [5 rows x 48 columns]

# %%
c = data['condition'].value_counts()
condition = c.index
c
# Out:
# robust       343
# frail_mci     76
# Name: condition, dtype: int64

# %%
for i in range(len(condition)):
    data['condition'].replace(condition[i], i, inplace = True)

data.head()
# Out:
#       mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  ...  \
# 0  ME01378          1   241  13.0    20  33.5   150   5.25   0.46     87  ...
# 1  ME02832          1   444  43.8    16  87.0   134   4.65   0.40     85  ...
# 2  ME02909          1  1476  54.5    16  57.0   119   3.80   0.36     94  ...
# 3  ME02998          1   339  25.9    18  63.8   135   4.89   0.42     86  ...
# 4  ME03061          1   287  23.8    20  95.5   146   5.18   0.44     85  ...
#
#    B2_d6  B2_d7  B2_d8  B2_d9    B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 0     10     21     22     17   1.3    7.0  1.010   0.69    4.7  5.9
# 1     10     14     20     15  13.4    6.0  1.005   1.29    4.5  5.8
# 2     18     17     35     21   0.2    7.5  1.012   1.90    4.1  5.8
# 3     13     16     25     13  16.8    5.0  1.017   1.32    4.0  6.0
# 4     18     22     25     24   1.4    7.5  1.006   2.94    4.6  6.1
#
# [5 rows x 48 columns]

# %%
data.tail()
# Out:
#         mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  \
# 414  MV00454          0   220  24.6    19  67.5   138   4.66   0.42     91
# 415  MV00456          0   334  20.1    18  51.0   139   4.63   0.42     91
# 416  MV00460          0   418  54.4    17  61.0   122   4.18   0.38     90
# 417  MV00502          0   393  38.2    18  43.1   136   4.57   0.43     94
# 418  MV00510          0   371  23.2    24  55.9   127   4.41   0.40     90
#
#      ...  B2_d6  B2_d7  B2_d8  B2_d9   B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 414  ...     20     10     17      8  6.6    7.0  1.015   1.29    4.5  6.2
# 415  ...     16     22     35     40  1.0    6.0  1.015   1.88    3.9  5.6
# 416  ...     19     20     23     15  0.4    6.5  1.005   3.58    4.0  5.6
# 417  ...     13     11     22     23  0.7    7.0  1.009   0.92    4.1  6.0
# 418  ...     13     14     16     12  7.5    8.0  1.017   2.45    4.5  6.2
#
# [5 rows x 48 columns]

# %%
y = data['condition']

features = ['A1_1', 'A1_2', 'A2_1', 'A3_1', 'B1_a', 'B1_a1', 'B1_a2',
       'B1_a3', 'B1_a4', 'B1_a5', 'B1_a6', 'B1_b', 'B1_b1', 'B1_b2', 'B1_b3',
       'B1_c', 'B1_d', 'B2_a1', 'B2_a2', 'B2_a3', 'B2_a4', 'B2_a5', 'B2_b1',
       'B2_b2', 'B2_b3', 'B2_c1', 'B2_c2', 'B2_c4', 'B2_c5', 'B2_c6', 'B2_c7',
       'B2_d1', 'B2_d2', 'B2_d3', 'B2_d4', 'B2_d5', 'B2_d6', 'B2_d7', 'B2_d8',
       'B2_d9', 'B3', 'B4_a2', 'B4_a5', 'B5_a2', 'B5_a3', 'B6']
X_old = data[features]

X = X_old
X = StandardScaler().fit_transform(X_old)
X = MinMaxScaler().fit_transform(X_old)

# %%
# sampling_strategy = {0: 76, 1: 76}
# undersample = RandomUnderSampler(sampling_strategy=sampling_strategy)

# X, y = undersample.fit_resample(X, y)

# Transform the dataset using SMOTE
# oversample = SMOTE()
# X, y = oversample.fit_resample(X, y)

# %%
# Summarise the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 343, 1: 76})

# %%
# HOLDOUT METHOD:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 1)

# Logistic Regression

log_model = LogisticRegression()
log_model.fit(X_train, y_train)
print("Logistic Regression:", log_model.score(X_test, y_test).round(3))

# Linear Discriminant Analysis

lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X_train, y_train)
print("Linear Discriminant Analysis:", lda_model.score(X_test, y_test).round(3))

# K-Nearest Neigbors

knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
print("K-Nearest Neigbors:", knn_model.score(X_test, y_test).round(3))

# Classification and Regression Trees

cart_model = DecisionTreeClassifier()
cart_model.fit(X_train, y_train)
print("Classification and Regression Trees:", cart_model.score(X_test, y_test).round(3))

# Gaussian Naive Bayes

gnb_model = GaussianNB()
gnb_model.fit(X_train, y_train)
print("Gaussian Naive Bayes:", gnb_model.score(X_test, y_test).round(3))

# Support Vector Machines

svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X_train, y_train)
print("Support Vector Machines:", svm_model.score(X_test, y_test).round(3))

# Random Forest Classifier

rfc_model = RandomForestClassifier()
rfc_model.fit(X_train, y_train)
print("Random Forest Classifier:", rfc_model.score(X_test, y_test).round(3))
# Out:
# Logistic Regression: 0.845
# Linear Discriminant Analysis: 0.815
# K-Nearest Neigbors: 0.833
# Classification and Regression Trees: 0.756
# Gaussian Naive Bayes: 0.804
# Support Vector Machines: 0.839
# Random Forest Classifier: 0.839

# %%
# Calculating Performance Metrics for Holdout

# %%
# Calculating for Logistic Regression
log_pred = log_model.predict(X_test)

print('Performance Metrics for Logistic Regression:\n')
print(accuracy_score(y_test, log_pred).round(5), '\n')
print(confusion_matrix(y_test, log_pred), '\n')
print(classification_report(y_test, log_pred))
# Out:
# Performance Metrics for Logistic Regression:
#
# 0.84524
#
# [[139   2]
#  [ 24   3]]
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       141
#            1       0.60      0.11      0.19        27
#
#     accuracy                           0.85       168
#    macro avg       0.73      0.55      0.55       168
# weighted avg       0.81      0.85      0.80       168

# %%
# Calculating for LDA
lda_pred = lda_model.predict(X_test)

print('Performance Metrics for LDA:\n')
print(accuracy_score(y_test, lda_pred).round(5), '\n')
print(confusion_matrix(y_test, lda_pred), '\n')
print(classification_report(y_test, lda_pred))
# Out:
# Performance Metrics for LDA:
#
# 0.81548
#
# [[125  16]
#  [ 15  12]]
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       141
#            1       0.43      0.44      0.44        27
#
#     accuracy                           0.82       168
#    macro avg       0.66      0.67      0.66       168
# weighted avg       0.82      0.82      0.82       168

# %%
# Calculating for kNN
knn_pred = knn_model.predict(X_test)

print('Performance Metrics for KNN:\n')
print(accuracy_score(y_test, knn_pred).round(5), '\n')
print(confusion_matrix(y_test, knn_pred), '\n')
print(classification_report(y_test, knn_pred))
# Out:
# Performance Metrics for KNN:
#
# 0.83333
#
# [[140   1]
#  [ 27   0]]
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91       141
#            1       0.00      0.00      0.00        27
#
#     accuracy                           0.83       168
#    macro avg       0.42      0.50      0.45       168
# weighted avg       0.70      0.83      0.76       168

# %%
# Calculating for CART
cart_pred = cart_model.predict(X_test)

print('Performance Metrics for CART:\n')
print(accuracy_score(y_test, cart_pred).round(5), '\n')
print(confusion_matrix(y_test, cart_pred), '\n')
print(classification_report(y_test, cart_pred))
# Out:
# Performance Metrics for CART:
#
# 0.75595
#
# [[119  22]
#  [ 19   8]]
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       141
#            1       0.27      0.30      0.28        27
#
#     accuracy                           0.76       168
#    macro avg       0.56      0.57      0.57       168
# weighted avg       0.77      0.76      0.76       168

# %%
# Calculating for GNB
gnb_pred = log_model.predict(X_test)

print('Performance Metrics for GNB:\n')
print(accuracy_score(y_test, gnb_pred).round(5), '\n')
print(confusion_matrix(y_test, gnb_pred), '\n')
print(classification_report(y_test, gnb_pred))
# Out:
# Performance Metrics for GNB:
#
# 0.84524
#
# [[139   2]
#  [ 24   3]]
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       141
#            1       0.60      0.11      0.19        27
#
#     accuracy                           0.85       168
#    macro avg       0.73      0.55      0.55       168
# weighted avg       0.81      0.85      0.80       168

# %%
# Calculating for Support Vector Machine
svm_pred = svm_model.predict(X_test)

print('Performance Metrics for SVM:\n')
print(accuracy_score(y_test, svm_pred).round(5), '\n')
print(confusion_matrix(y_test, svm_pred), '\n')
print(classification_report(y_test, svm_pred))
# Out:
# Performance Metrics for SVM:
#
# 0.83929
#
# [[139   2]
#  [ 25   2]]
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       141
#            1       0.50      0.07      0.13        27
#
#     accuracy                           0.84       168
#    macro avg       0.67      0.53      0.52       168
# weighted avg       0.79      0.84      0.79       168

# %%
# Calculating for Random Forest Classifier
rfc_pred = rfc_model.predict(X_test)

print('Performance Metrics for RFC:\n')
print(accuracy_score(y_test, rfc_pred).round(5), '\n')
print(confusion_matrix(y_test, rfc_pred), '\n')
print(classification_report(y_test, rfc_pred))
# Out:
# Performance Metrics for RFC:
#
# 0.83929
#
# [[136   5]
#  [ 22   5]]
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       141
#            1       0.50      0.19      0.27        27
#
#     accuracy                           0.84       168
#    macro avg       0.68      0.57      0.59       168
# weighted avg       0.80      0.84      0.81       168

# %%
# Obtain the top features from the classification results

# Logistic Regression

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(log_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# 25-hydroxy Vitamin D (nmol/L)             1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# ALT                                       1
# Urea (mmol/L)                             1
# Potassium (mmol/L)                        1
# Monocytes (/L)                            1
# Haemoglobin (g/L)                         2
# Vitamin B12 (pmol/L)                      3
# Creatinine (umol/L)                       4
# HbA1c                                     5
# Phosphate (mmol/L)                        6
# Total Bilirubin (µmol/L)                  7
# Lymphocytes (/L)                          8
# Chloride (mmol/L)                         9
# Total Protein (g/L)                      10
# pH                                       11
# MCH (pg)                                 12
# Free Tri-iodothyronine (FT3) (pmol/L)    13
# S.G.                                     14
# Neutrophils (/L)                         15
# GGT                                      16
# Albumin (g/L)                            17
# Triglyceride (mmol/L)                    18
# C-Reactive Protein                       19
# AST                                      20
# Alkaline Phosphatase (U/L)               21
# LDL Cholesterol (mmol/L)                 22
# MCHC (g/L)                               23
# Glucose (mmol/L)                         24
# MCV (fL)                                 25
# Thyroid Stimulating Hormone (mIU/L)      26
# Corrected Calcium (mmol/L)               27
# Albumin/Globulin ratio                   28
# Globulin (g/L)                           29
# White Cell Count (/L)                    30
# Platelets (/L)                           31
# Total Cholesterol (mmol/L)               32
# RDW (%)                                  33
# Calcium (mmol/L)                         34
# HDL Cholesterol (mmol/L)                 35
# Total Cholesterol/HDL Ratio              36
# Uric Acid (mmol/L)                       37

# %%
# Linear Discriminant Analysis

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(lda_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# ALT                                       1
# Serum Homocysteine (µmol/L)               1
# 25-hydroxy Vitamin D (nmol/L)             1
# AST                                       1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# MCV (fL)                                  1
# GGT                                       1
# White Cell Count (/L)                     1
# Neutrophils (/L)                          1
# Globulin (g/L)                            2
# Potassium (mmol/L)                        3
# Albumin/Globulin ratio                    4
# Vitamin B12 (pmol/L)                      5
# Total Bilirubin (µmol/L)                  6
# Platelets (/L)                            7
# Total Cholesterol (mmol/L)                8
# LDL Cholesterol (mmol/L)                  9
# Albumin (g/L)                            10
# HbA1c                                    11
# Urea (mmol/L)                            12
# C-Reactive Protein                       13
# Sodium (mmol/L)                          14
# Calcium (mmol/L)                         15
# Total Cholesterol/HDL Ratio              16
# Serum Folate (nmol/L)                    17
# Haemoglobin (g/L)                        18
# S.G.                                     19
# MCHC (g/L)                               20
# Lymphocytes (/L)                         21
# RDW (%)                                  22
# Glucose (mmol/L)                         23
# Chloride (mmol/L)                        24
# Creatinine (umol/L)                      25
# Total Protein (g/L)                      26
# pH                                       27
# MCH (pg)                                 28
# Thyroid Stimulating Hormone (mIU/L)      29
# Monocytes (/L)                           30
# Alkaline Phosphatase (U/L)               31
# Corrected Calcium (mmol/L)               32
# Uric Acid (mmol/L)                       33
# Free Tri-iodothyronine (FT3) (pmol/L)    34
# Triglyceride (mmol/L)                    35
# Phosphate (mmol/L)                       36
# HDL Cholesterol (mmol/L)                 37

# %%
# Classification and Regression Trees

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(cart_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# HbA1c                                     1
# Serum Folate (nmol/L)                     1
# Free Tri-iodothyronine (FT3) (pmol/L)     1
# PCV (L/L)                                 1
# Total Cholesterol (mmol/L)                1
# ALT                                       1
# Glucose (mmol/L)                          1
# Potassium (mmol/L)                        1
# Lymphocytes (/L)                          1
# Albumin (g/L)                             1
# Total Bilirubin (µmol/L)                  2
# C-Reactive Protein                        3
# Triglyceride (mmol/L)                     4
# Corrected Calcium (mmol/L)                5
# Total Protein (g/L)                       6
# Neutrophils (/L)                          7
# Calcium (mmol/L)                          8
# Uric Acid (mmol/L)                        9
# RDW (%)                                  10
# RBC (/L)                                 11
# MCV (fL)                                 12
# MCH (pg)                                 13
# Alkaline Phosphatase (U/L)               14
# Serum Homocysteine (µmol/L)              15
# Haemoglobin (g/L)                        16
# Thyroid Stimulating Hormone (mIU/L)      17
# GGT                                      18
# 25-hydroxy Vitamin D (nmol/L)            19
# Phosphate (mmol/L)                       20
# MCHC (g/L)                               21
# AST                                      22
# White Cell Count (/L)                    23
# LDL Cholesterol (mmol/L)                 24
# Platelets (/L)                           25
# Albumin/Globulin ratio                   26
# Globulin (g/L)                           27
# S.G.                                     28
# pH                                       29
# Creatinine (umol/L)                      30
# Monocytes (/L)                           31
# Urea (mmol/L)                            32
# HDL Cholesterol (mmol/L)                 33
# Chloride (mmol/L)                        34
# Sodium (mmol/L)                          35
# Total Cholesterol/HDL Ratio              36
# Vitamin B12 (pmol/L)                     37

# %%
# Support Vector Machines

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(svm_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Vitamin B12 (pmol/L)                      1
# ALT                                       1
# Serum Homocysteine (µmol/L)               1
# 25-hydroxy Vitamin D (nmol/L)             1
# AST                                       1
# Urea (mmol/L)                             1
# PCV (L/L)                                 1
# Potassium (mmol/L)                        1
# Monocytes (/L)                            1
# Neutrophils (/L)                          1
# HbA1c                                     2
# Creatinine (umol/L)                       3
# Sodium (mmol/L)                           4
# Alkaline Phosphatase (U/L)                5
# GGT                                       6
# Serum Folate (nmol/L)                     7
# RBC (/L)                                  8
# MCV (fL)                                  9
# Total Protein (g/L)                      10
# Haemoglobin (g/L)                        11
# Thyroid Stimulating Hormone (mIU/L)      12
# Calcium (mmol/L)                         13
# S.G.                                     14
# pH                                       15
# White Cell Count (/L)                    16
# Lymphocytes (/L)                         17
# Globulin (g/L)                           18
# Albumin (g/L)                            19
# Chloride (mmol/L)                        20
# Free Tri-iodothyronine (FT3) (pmol/L)    21
# HDL Cholesterol (mmol/L)                 22
# MCH (pg)                                 23
# Total Bilirubin (µmol/L)                 24
# C-Reactive Protein                       25
# Phosphate (mmol/L)                       26
# Platelets (/L)                           27
# Albumin/Globulin ratio                   28
# Glucose (mmol/L)                         29
# Total Cholesterol/HDL Ratio              30
# LDL Cholesterol (mmol/L)                 31
# MCHC (g/L)                               32
# Uric Acid (mmol/L)                       33
# Total Cholesterol (mmol/L)               34
# Triglyceride (mmol/L)                    35
# RDW (%)                                  36
# Corrected Calcium (mmol/L)               37

# %%
# Random Forest Classifier

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(rfc_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Serum Folate (nmol/L)                     1
# Potassium (mmol/L)                        1
# 25-hydroxy Vitamin D (nmol/L)             1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# C-Reactive Protein                        1
# Glucose (mmol/L)                          1
# Free Tri-iodothyronine (FT3) (pmol/L)     1
# Creatinine (umol/L)                       1
# Neutrophils (/L)                          1
# Haemoglobin (g/L)                         2
# Vitamin B12 (pmol/L)                      3
# ALT                                       4
# Lymphocytes (/L)                          5
# Uric Acid (mmol/L)                        6
# Platelets (/L)                            7
# Serum Homocysteine (µmol/L)               8
# LDL Cholesterol (mmol/L)                  9
# Urea (mmol/L)                            10
# Phosphate (mmol/L)                       11
# White Cell Count (/L)                    12
# HbA1c                                    13
# Triglyceride (mmol/L)                    14
# GGT                                      15
# HDL Cholesterol (mmol/L)                 16
# Monocytes (/L)                           17
# MCV (fL)                                 18
# Chloride (mmol/L)                        19
# Calcium (mmol/L)                         20
# Alkaline Phosphatase (U/L)               21
# Corrected Calcium (mmol/L)               22
# S.G.                                     23
# Total Protein (g/L)                      24
# Total Bilirubin (µmol/L)                 25
# Sodium (mmol/L)                          26
# Globulin (g/L)                           27
# Total Cholesterol (mmol/L)               28
# MCHC (g/L)                               29
# RDW (%)                                  30
# Total Cholesterol/HDL Ratio              31
# Albumin (g/L)                            32
# Thyroid Stimulating Hormone (mIU/L)      33
# AST                                      34
# MCH (pg)                                 35
# Albumin/Globulin ratio                   36
# pH                                       37

# %%
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedStratifiedKFold
import matplotlib.pyplot as plt

# get a list of models to evaluate
def get_models():
    models = dict()
    # Logistic Regression
    rfe = RFE(log_model, 10)
    model = DecisionTreeClassifier()
    models['LOG'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Linear Discriminant Analysis
    rfe = RFE(lda_model, 10)
    model = DecisionTreeClassifier()
    models['LDA'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Classification & Regression Trees
    rfe = RFE(cart_model, 10)
    model = DecisionTreeClassifier()
    models['CART'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Support Vector Machines
    rfe = RFE(svm_model, 10)
    model = DecisionTreeClassifier()
    models['SVM'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Random Forest Classifier
    rfe = RFE(rfc_model, 10)
    model = DecisionTreeClassifier()
    models['RFC'] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    return scores

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X_train, y_train)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# >LOG 0.737 (0.072)
# >LDA 0.738 (0.068)
# >CART 0.745 (0.073)
# >SVM 0.722 (0.068)
# >RFC 0.732 (0.071)

# %%
# CROSS-VALIDATION:

# %%
# Logistic Regression

log_model = LogisticRegression()
log_model.fit(X, y)
scores = cross_val_score(log_model, X, y, cv=5)
print("Logistic Regression: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Linear Discriminant Analysis

lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X, y)
scores = cross_val_score(lda_model, X, y, cv=5)
print("Linear Discriminant Analysis: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# K-Nearest Neigbors

knn_model = KNeighborsClassifier()
knn_model.fit(X, y)
scores = cross_val_score(knn_model, X, y, cv=5)
print("K-Nearest Neighbors: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Classification and Regression Trees

cart_model = DecisionTreeClassifier()
cart_model.fit(X, y)
scores = cross_val_score(cart_model, X, y, cv=5)
print("Classification and Regression Trees: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Gaussian Naive Bayes

gnb_model = GaussianNB()
gnb_model.fit(X, y)
scores = cross_val_score(gnb_model, X, y, cv=5)
print("Gaussian Naive Bayes: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Support Vector Machines

svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X, y)
scores = cross_val_score(svm_model, X, y, cv=5)
print("Support Vector Machines: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Random Forest Classifier

rfc_model = RandomForestClassifier()
rfc_model.fit(X, y)
scores = cross_val_score(rfc_model, X, y, cv=5)
print("Random Forest Classifier: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))
# Out:
# Logistic Regression: 0.835 accuracy with a standard deviation of 0.023
# Linear Discriminant Analysis: 0.809 accuracy with a standard deviation of 0.043
# K-Nearest Neighbors: 0.816 accuracy with a standard deviation of 0.006
# Classification and Regression Trees: 0.766 accuracy with a standard deviation of 0.038
# Gaussian Naive Bayes: 0.807 accuracy with a standard deviation of 0.029
# Support Vector Machines: 0.821 accuracy with a standard deviation of 0.014
# Random Forest Classifier: 0.828 accuracy with a standard deviation of 0.020

# %%
# Producing Cross-Validation Classification Reports for each Algorithm

# %%
# Logistic Regression
scores = cross_val_score(log_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.89        68
#            1       0.50      0.06      0.11        16
#
#     accuracy                           0.81        84
#    macro avg       0.66      0.52      0.50        84
# weighted avg       0.76      0.81      0.74        84
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90        69
#            1       0.50      0.13      0.21        15
#
#     accuracy                           0.82        84
#    macro avg       0.67      0.55      0.55        84
# weighted avg       0.78      0.82      0.78        84
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90        69
#            1       0.50      0.13      0.21        15
#
#     accuracy                           0.82        84
#    macro avg       0.67      0.55      0.55        84
# weighted avg       0.78      0.82      0.78        84
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92        69
#            1       0.80      0.27      0.40        15
#
#     accuracy                           0.86        84
#    macro avg       0.83      0.63      0.66        84
# weighted avg       0.85      0.86      0.83        84
#
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93        68
#            1       1.00      0.27      0.42        15
#
#     accuracy                           0.87        83
#    macro avg       0.93      0.63      0.67        83
# weighted avg       0.89      0.87      0.83        83
#
# [0.80952381 0.82142857 0.82142857 0.85714286 0.86746988]

# %%
# Linear Discriminant Analysis
scores = cross_val_score(lda_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87        68
#            1       0.29      0.12      0.17        16
#
#     accuracy                           0.77        84
#    macro avg       0.55      0.53      0.52        84
# weighted avg       0.72      0.77      0.74        84
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        69
#            1       0.47      0.47      0.47        15
#
#     accuracy                           0.81        84
#    macro avg       0.68      0.68      0.68        84
# weighted avg       0.81      0.81      0.81        84
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        69
#            1       0.33      0.40      0.36        15
#
#     accuracy                           0.75        84
#    macro avg       0.60      0.61      0.60        84
# weighted avg       0.77      0.75      0.76        84
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92        69
#            1       0.67      0.40      0.50        15
#
#     accuracy                           0.86        84
#    macro avg       0.77      0.68      0.71        84
# weighted avg       0.84      0.86      0.84        84
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        68
#            1       0.60      0.60      0.60        15
#
#     accuracy                           0.86        83
#    macro avg       0.76      0.76      0.76        83
# weighted avg       0.86      0.86      0.86        83
#
# [0.77380952 0.80952381 0.75       0.85714286 0.85542169]

# %%
# K-Nearest Neigbors
knn_model = KNeighborsClassifier()
knn_model.fit(X, y)
scores = cross_val_score(knn_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89        68
#            1       0.00      0.00      0.00        16
#
#     accuracy                           0.81        84
#    macro avg       0.40      0.50      0.45        84
# weighted avg       0.66      0.81      0.72        84
#
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90        69
#            1       0.00      0.00      0.00        15
#
#     accuracy                           0.82        84
#    macro avg       0.41      0.50      0.45        84
# weighted avg       0.67      0.82      0.74        84
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90        69
#            1       0.50      0.07      0.12        15
#
#     accuracy                           0.82        84
#    macro avg       0.66      0.53      0.51        84
# weighted avg       0.77      0.82      0.76        84
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.89        69
#            1       0.00      0.00      0.00        15
#
#     accuracy                           0.81        84
#    macro avg       0.41      0.49      0.45        84
# weighted avg       0.67      0.81      0.73        84
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90        68
#            1       0.50      0.07      0.12        15
#
#     accuracy                           0.82        83
#    macro avg       0.66      0.53      0.51        83
# weighted avg       0.77      0.82      0.76        83
#
# [0.80952381 0.82142857 0.82142857 0.80952381 0.81927711]
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Classification and Regression Trees
cart_model = DecisionTreeClassifier()
cart_model.fit(X, y)
scores = cross_val_score(cart_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88        68
#            1       0.44      0.25      0.32        16
#
#     accuracy                           0.80        84
#    macro avg       0.64      0.59      0.60        84
# weighted avg       0.76      0.80      0.77        84
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        69
#            1       0.33      0.27      0.30        15
#
#     accuracy                           0.77        84
#    macro avg       0.59      0.58      0.58        84
# weighted avg       0.76      0.77      0.76        84
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81        69
#            1       0.25      0.33      0.29        15
#
#     accuracy                           0.70        84
#    macro avg       0.55      0.56      0.55        84
# weighted avg       0.74      0.70      0.72        84
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83        69
#            1       0.25      0.27      0.26        15
#
#     accuracy                           0.73        84
#    macro avg       0.54      0.55      0.55        84
# weighted avg       0.73      0.73      0.73        84
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90        68
#            1       0.56      0.60      0.58        15
#
#     accuracy                           0.84        83
#    macro avg       0.74      0.75      0.74        83
# weighted avg       0.85      0.84      0.85        83
#
# [0.79761905 0.77380952 0.70238095 0.72619048 0.84337349]

# %%
# Gaussian Naive Bayes
gnb_model = GaussianNB()
gnb_model.fit(X, y)
scores = cross_val_score(gnb_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.90        68
#            1       0.56      0.31      0.40        16
#
#     accuracy                           0.82        84
#    macro avg       0.70      0.63      0.65        84
# weighted avg       0.80      0.82      0.80        84
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89        69
#            1       0.50      0.53      0.52        15
#
#     accuracy                           0.82        84
#    macro avg       0.70      0.71      0.70        84
# weighted avg       0.83      0.82      0.82        84
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        69
#            1       0.33      0.27      0.30        15
#
#     accuracy                           0.77        84
#    macro avg       0.59      0.58      0.58        84
# weighted avg       0.76      0.77      0.76        84
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        69
#            1       0.58      0.47      0.52        15
#
#     accuracy                           0.85        84
#    macro avg       0.74      0.70      0.71        84
# weighted avg       0.83      0.85      0.84        84
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86        68
#            1       0.39      0.47      0.42        15
#
#     accuracy                           0.77        83
#    macro avg       0.63      0.65      0.64        83
# weighted avg       0.79      0.77      0.78        83
#
# [0.82142857 0.82142857 0.77380952 0.8452381  0.77108434]

# %%
# Support Vector Machines
svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X, y)
scores = cross_val_score(svm_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.89        68
#            1       0.50      0.06      0.11        16
#
#     accuracy                           0.81        84
#    macro avg       0.66      0.52      0.50        84
# weighted avg       0.76      0.81      0.74        84
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89        69
#            1       0.33      0.07      0.11        15
#
#     accuracy                           0.81        84
#    macro avg       0.58      0.52      0.50        84
# weighted avg       0.74      0.81      0.75        84
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.89        69
#            1       0.00      0.00      0.00        15
#
#     accuracy                           0.81        84
#    macro avg       0.41      0.49      0.45        84
# weighted avg       0.67      0.81      0.73        84
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91        69
#            1       0.67      0.13      0.22        15
#
#     accuracy                           0.83        84
#    macro avg       0.75      0.56      0.56        84
# weighted avg       0.81      0.83      0.78        84
#
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91        68
#            1       1.00      0.13      0.24        15
#
#     accuracy                           0.84        83
#    macro avg       0.92      0.57      0.57        83
# weighted avg       0.87      0.84      0.79        83
#
# [0.80952381 0.80952381 0.80952381 0.83333333 0.84337349]

# %%
# Random Forest Classifier
rfc_model = RandomForestClassifier()
rfc_model.fit(X, y)
scores = cross_val_score(rfc_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90        68
#            1       0.67      0.12      0.21        16
#
#     accuracy                           0.82        84
#    macro avg       0.75      0.56      0.55        84
# weighted avg       0.80      0.82      0.77        84
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88        69
#            1       0.20      0.07      0.10        15
#
#     accuracy                           0.79        84
#    macro avg       0.51      0.50      0.49        84
# weighted avg       0.71      0.79      0.74        84
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90        69
#            1       0.50      0.13      0.21        15
#
#     accuracy                           0.82        84
#    macro avg       0.67      0.55      0.55        84
# weighted avg       0.78      0.82      0.78        84
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91        69
#            1       0.75      0.20      0.32        15
#
#     accuracy                           0.85        84
#    macro avg       0.80      0.59      0.61        84
# weighted avg       0.83      0.85      0.81        84
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91        68
#            1       0.67      0.27      0.38        15
#
#     accuracy                           0.84        83
#    macro avg       0.76      0.62      0.65        83
# weighted avg       0.82      0.84      0.81        83
#
# [0.82142857 0.78571429 0.82142857 0.8452381  0.84337349]

# %%
# Logistic Regression

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(log_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# 25-hydroxy Vitamin D (nmol/L)             1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# ALT                                       1
# Urea (mmol/L)                             1
# Potassium (mmol/L)                        1
# Monocytes (/L)                            1
# Haemoglobin (g/L)                         2
# Vitamin B12 (pmol/L)                      3
# Creatinine (umol/L)                       4
# HbA1c                                     5
# Phosphate (mmol/L)                        6
# Total Bilirubin (µmol/L)                  7
# Lymphocytes (/L)                          8
# Chloride (mmol/L)                         9
# Total Protein (g/L)                      10
# pH                                       11
# MCH (pg)                                 12
# Free Tri-iodothyronine (FT3) (pmol/L)    13
# S.G.                                     14
# Neutrophils (/L)                         15
# GGT                                      16
# Albumin (g/L)                            17
# Triglyceride (mmol/L)                    18
# C-Reactive Protein                       19
# AST                                      20
# Alkaline Phosphatase (U/L)               21
# LDL Cholesterol (mmol/L)                 22
# MCHC (g/L)                               23
# Glucose (mmol/L)                         24
# MCV (fL)                                 25
# Thyroid Stimulating Hormone (mIU/L)      26
# Corrected Calcium (mmol/L)               27
# Albumin/Globulin ratio                   28
# Globulin (g/L)                           29
# White Cell Count (/L)                    30
# Platelets (/L)                           31
# Total Cholesterol (mmol/L)               32
# RDW (%)                                  33
# Calcium (mmol/L)                         34
# HDL Cholesterol (mmol/L)                 35
# Total Cholesterol/HDL Ratio              36
# Uric Acid (mmol/L)                       37

# %%
# Linear Discriminant Analysis

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(lda_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# ALT                                       1
# Serum Homocysteine (µmol/L)               1
# 25-hydroxy Vitamin D (nmol/L)             1
# AST                                       1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# MCV (fL)                                  1
# GGT                                       1
# White Cell Count (/L)                     1
# Neutrophils (/L)                          1
# Globulin (g/L)                            2
# Potassium (mmol/L)                        3
# Albumin/Globulin ratio                    4
# Vitamin B12 (pmol/L)                      5
# Total Bilirubin (µmol/L)                  6
# Platelets (/L)                            7
# Total Cholesterol (mmol/L)                8
# LDL Cholesterol (mmol/L)                  9
# Albumin (g/L)                            10
# HbA1c                                    11
# Urea (mmol/L)                            12
# C-Reactive Protein                       13
# Sodium (mmol/L)                          14
# Calcium (mmol/L)                         15
# Total Cholesterol/HDL Ratio              16
# Serum Folate (nmol/L)                    17
# Haemoglobin (g/L)                        18
# S.G.                                     19
# MCHC (g/L)                               20
# Lymphocytes (/L)                         21
# RDW (%)                                  22
# Glucose (mmol/L)                         23
# Chloride (mmol/L)                        24
# Creatinine (umol/L)                      25
# Total Protein (g/L)                      26
# pH                                       27
# MCH (pg)                                 28
# Thyroid Stimulating Hormone (mIU/L)      29
# Monocytes (/L)                           30
# Alkaline Phosphatase (U/L)               31
# Corrected Calcium (mmol/L)               32
# Uric Acid (mmol/L)                       33
# Free Tri-iodothyronine (FT3) (pmol/L)    34
# Triglyceride (mmol/L)                    35
# Phosphate (mmol/L)                       36
# HDL Cholesterol (mmol/L)                 37

# %%
# Classification and Regression Trees

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(cart_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# HbA1c                                     1
# Total Cholesterol (mmol/L)                1
# Glucose (mmol/L)                          1
# Albumin (g/L)                             1
# Potassium (mmol/L)                        1
# PCV (L/L)                                 1
# Free Tri-iodothyronine (FT3) (pmol/L)     1
# ALT                                       1
# C-Reactive Protein                        1
# Serum Folate (nmol/L)                     1
# Lymphocytes (/L)                          2
# Total Bilirubin (µmol/L)                  3
# Triglyceride (mmol/L)                     4
# Phosphate (mmol/L)                        5
# Corrected Calcium (mmol/L)                6
# MCHC (g/L)                                7
# MCV (fL)                                  8
# Uric Acid (mmol/L)                        9
# Creatinine (umol/L)                      10
# MCH (pg)                                 11
# Haemoglobin (g/L)                        12
# RBC (/L)                                 13
# Thyroid Stimulating Hormone (mIU/L)      14
# 25-hydroxy Vitamin D (nmol/L)            15
# Serum Homocysteine (µmol/L)              16
# Total Protein (g/L)                      17
# Albumin/Globulin ratio                   18
# Calcium (mmol/L)                         19
# Urea (mmol/L)                            20
# RDW (%)                                  21
# Platelets (/L)                           22
# S.G.                                     23
# White Cell Count (/L)                    24
# LDL Cholesterol (mmol/L)                 25
# AST                                      26
# Neutrophils (/L)                         27
# Globulin (g/L)                           28
# GGT                                      29
# Alkaline Phosphatase (U/L)               30
# Monocytes (/L)                           31
# HDL Cholesterol (mmol/L)                 32
# pH                                       33
# Chloride (mmol/L)                        34
# Sodium (mmol/L)                          35
# Total Cholesterol/HDL Ratio              36
# Vitamin B12 (pmol/L)                     37

# %%
# Support Vector Machines

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(svm_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Vitamin B12 (pmol/L)                      1
# ALT                                       1
# Serum Homocysteine (µmol/L)               1
# 25-hydroxy Vitamin D (nmol/L)             1
# AST                                       1
# Urea (mmol/L)                             1
# PCV (L/L)                                 1
# Potassium (mmol/L)                        1
# Monocytes (/L)                            1
# Neutrophils (/L)                          1
# HbA1c                                     2
# Creatinine (umol/L)                       3
# Sodium (mmol/L)                           4
# Alkaline Phosphatase (U/L)                5
# GGT                                       6
# Serum Folate (nmol/L)                     7
# RBC (/L)                                  8
# MCV (fL)                                  9
# Total Protein (g/L)                      10
# Haemoglobin (g/L)                        11
# Thyroid Stimulating Hormone (mIU/L)      12
# Calcium (mmol/L)                         13
# S.G.                                     14
# pH                                       15
# White Cell Count (/L)                    16
# Lymphocytes (/L)                         17
# Globulin (g/L)                           18
# Albumin (g/L)                            19
# Chloride (mmol/L)                        20
# Free Tri-iodothyronine (FT3) (pmol/L)    21
# HDL Cholesterol (mmol/L)                 22
# MCH (pg)                                 23
# Total Bilirubin (µmol/L)                 24
# C-Reactive Protein                       25
# Phosphate (mmol/L)                       26
# Platelets (/L)                           27
# Albumin/Globulin ratio                   28
# Glucose (mmol/L)                         29
# Total Cholesterol/HDL Ratio              30
# LDL Cholesterol (mmol/L)                 31
# MCHC (g/L)                               32
# Uric Acid (mmol/L)                       33
# Total Cholesterol (mmol/L)               34
# Triglyceride (mmol/L)                    35
# RDW (%)                                  36
# Corrected Calcium (mmol/L)               37

# %%
# Random Forest Classifier

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(rfc_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Neutrophils (/L)                          1
# Serum Folate (nmol/L)                     1
# Potassium (mmol/L)                        1
# 25-hydroxy Vitamin D (nmol/L)             1
# Haemoglobin (g/L)                         1
# Free Tri-iodothyronine (FT3) (pmol/L)     1
# PCV (L/L)                                 1
# ALT                                       1
# Creatinine (umol/L)                       1
# Glucose (mmol/L)                          1
# C-Reactive Protein                        2
# Vitamin B12 (pmol/L)                      3
# RBC (/L)                                  4
# Platelets (/L)                            5
# Uric Acid (mmol/L)                        6
# Serum Homocysteine (µmol/L)               7
# Urea (mmol/L)                             8
# LDL Cholesterol (mmol/L)                  9
# Lymphocytes (/L)                         10
# White Cell Count (/L)                    11
# Chloride (mmol/L)                        12
# HDL Cholesterol (mmol/L)                 13
# Alkaline Phosphatase (U/L)               14
# Phosphate (mmol/L)                       15
# Total Cholesterol/HDL Ratio              16
# Total Cholesterol (mmol/L)               17
# HbA1c                                    18
# Thyroid Stimulating Hormone (mIU/L)      19
# Monocytes (/L)                           20
# Total Protein (g/L)                      21
# Triglyceride (mmol/L)                    22
# Calcium (mmol/L)                         23
# MCV (fL)                                 24
# Sodium (mmol/L)                          25
# GGT                                      26
# RDW (%)                                  27
# S.G.                                     28
# Total Bilirubin (µmol/L)                 29
# MCH (pg)                                 30
# Corrected Calcium (mmol/L)               31
# MCHC (g/L)                               32
# Globulin (g/L)                           33
# AST                                      34
# Albumin/Globulin ratio                   35
# Albumin (g/L)                            36
# pH                                       37

# %%
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedStratifiedKFold
import matplotlib.pyplot as plt

# get a list of models to evaluate
def get_models():
    models = dict()
    # Logistic Regression
    rfe = RFE(log_model, 10)
    model = DecisionTreeClassifier()
    models['LOG'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Linear Discriminant Analysis
    rfe = RFE(lda_model, 10)
    model = DecisionTreeClassifier()
    models['LDA'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Classification & Regression Trees
    rfe = RFE(cart_model, 10)
    model = DecisionTreeClassifier()
    models['CART'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Support Vector Machines
    rfe = RFE(svm_model, 10)
    model = DecisionTreeClassifier()
    models['SVM'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Random Forest Classifier
    rfe = RFE(rfc_model, 10)
    model = DecisionTreeClassifier()
    models['RFC'] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    return scores

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X_train, y_train)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# >LOG 0.737 (0.064)
# >LDA 0.732 (0.066)
# >CART 0.741 (0.076)
# >SVM 0.722 (0.069)
# >RFC 0.734 (0.085)

# %%
# Test 5: Using New Dataset, 76 Robust with 76 Frail+MCI

# %%
# Pre-parse the dataset
data = RobustFrailMCIpreprocess("rawfile_robust_frailmci.csv")
# Out:
# robust       368
# frail_mci     86
# Name: condition, dtype: int64
#
# ####################################################################
# Number of Rows of Dataframe:
# 454
# Number of Columns of Dataframe:
# 59
#
# ####################################################################
# Threshold for number of NULLs in a column: 0.1095
# Number of Columns before Parsing for Too Many NULLs in a column:
# 59
# Number of Columns after Parsing for Too Many NULLs in a column:
# 51
#
# Columns Removed:
# B1_b5
# B4_a1
# B4_a3
# B4_a4
# B4_a6
# B4_b1
# B4_b3
# B5_a1
#
# ####################################################################
# Number of Columns after dropping B1_b4, B2_c3, B4_b2 for inconsistent data types:
# 48
#
# ####################################################################
# Number of Rows before Parsing NULLs in data:
# 454
# Number of Rows after Parsing NULLs in data:
# 419

# %%
# Taking only Frail+MCI and Robust classes

df1 = data[data.condition == 'frail_mci']
df1 = df1.reset_index(drop=True)

df2 = data[data.condition == 'robust']
df2 = df2.reset_index(drop=True)

data = pd.concat([df1, df2], ignore_index=True)

# %%
data.head()
# Out:
#       mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  ...  \
# 0  ME01378  frail_mci   241  13.0    20  33.5   150   5.25   0.46     87  ...
# 1  ME02832  frail_mci   444  43.8    16  87.0   134   4.65   0.40     85  ...
# 2  ME02909  frail_mci  1476  54.5    16  57.0   119   3.80   0.36     94  ...
# 3  ME02998  frail_mci   339  25.9    18  63.8   135   4.89   0.42     86  ...
# 4  ME03061  frail_mci   287  23.8    20  95.5   146   5.18   0.44     85  ...
#
#    B2_d6  B2_d7  B2_d8  B2_d9    B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 0     10     21     22     17   1.3    7.0  1.010   0.69    4.7  5.9
# 1     10     14     20     15  13.4    6.0  1.005   1.29    4.5  5.8
# 2     18     17     35     21   0.2    7.5  1.012   1.90    4.1  5.8
# 3     13     16     25     13  16.8    5.0  1.017   1.32    4.0  6.0
# 4     18     22     25     24   1.4    7.5  1.006   2.94    4.6  6.1
#
# [5 rows x 48 columns]

# %%
data.tail()
# Out:
#         mtag condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  \
# 414  MV00454    robust   220  24.6    19  67.5   138   4.66   0.42     91
# 415  MV00456    robust   334  20.1    18  51.0   139   4.63   0.42     91
# 416  MV00460    robust   418  54.4    17  61.0   122   4.18   0.38     90
# 417  MV00502    robust   393  38.2    18  43.1   136   4.57   0.43     94
# 418  MV00510    robust   371  23.2    24  55.9   127   4.41   0.40     90
#
#      ...  B2_d6  B2_d7  B2_d8  B2_d9   B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 414  ...     20     10     17      8  6.6    7.0  1.015   1.29    4.5  6.2
# 415  ...     16     22     35     40  1.0    6.0  1.015   1.88    3.9  5.6
# 416  ...     19     20     23     15  0.4    6.5  1.005   3.58    4.0  5.6
# 417  ...     13     11     22     23  0.7    7.0  1.009   0.92    4.1  6.0
# 418  ...     13     14     16     12  7.5    8.0  1.017   2.45    4.5  6.2
#
# [5 rows x 48 columns]

# %%
c = data['condition'].value_counts()
condition = c.index
c
# Out:
# robust       343
# frail_mci     76
# Name: condition, dtype: int64

# %%
for i in range(len(condition)):
    data['condition'].replace(condition[i], i, inplace = True)

data.head()
# Out:
#       mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  ...  \
# 0  ME01378          1   241  13.0    20  33.5   150   5.25   0.46     87  ...
# 1  ME02832          1   444  43.8    16  87.0   134   4.65   0.40     85  ...
# 2  ME02909          1  1476  54.5    16  57.0   119   3.80   0.36     94  ...
# 3  ME02998          1   339  25.9    18  63.8   135   4.89   0.42     86  ...
# 4  ME03061          1   287  23.8    20  95.5   146   5.18   0.44     85  ...
#
#    B2_d6  B2_d7  B2_d8  B2_d9    B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 0     10     21     22     17   1.3    7.0  1.010   0.69    4.7  5.9
# 1     10     14     20     15  13.4    6.0  1.005   1.29    4.5  5.8
# 2     18     17     35     21   0.2    7.5  1.012   1.90    4.1  5.8
# 3     13     16     25     13  16.8    5.0  1.017   1.32    4.0  6.0
# 4     18     22     25     24   1.4    7.5  1.006   2.94    4.6  6.1
#
# [5 rows x 48 columns]

# %%
data.tail()
# Out:
#         mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  \
# 414  MV00454          0   220  24.6    19  67.5   138   4.66   0.42     91
# 415  MV00456          0   334  20.1    18  51.0   139   4.63   0.42     91
# 416  MV00460          0   418  54.4    17  61.0   122   4.18   0.38     90
# 417  MV00502          0   393  38.2    18  43.1   136   4.57   0.43     94
# 418  MV00510          0   371  23.2    24  55.9   127   4.41   0.40     90
#
#      ...  B2_d6  B2_d7  B2_d8  B2_d9   B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 414  ...     20     10     17      8  6.6    7.0  1.015   1.29    4.5  6.2
# 415  ...     16     22     35     40  1.0    6.0  1.015   1.88    3.9  5.6
# 416  ...     19     20     23     15  0.4    6.5  1.005   3.58    4.0  5.6
# 417  ...     13     11     22     23  0.7    7.0  1.009   0.92    4.1  6.0
# 418  ...     13     14     16     12  7.5    8.0  1.017   2.45    4.5  6.2
#
# [5 rows x 48 columns]

# %%
y = data['condition']

features = ['A1_1', 'A1_2', 'A2_1', 'A3_1', 'B1_a', 'B1_a1', 'B1_a2',
       'B1_a3', 'B1_a4', 'B1_a5', 'B1_a6', 'B1_b', 'B1_b1', 'B1_b2', 'B1_b3',
       'B1_c', 'B1_d', 'B2_a1', 'B2_a2', 'B2_a3', 'B2_a4', 'B2_a5', 'B2_b1',
       'B2_b2', 'B2_b3', 'B2_c1', 'B2_c2', 'B2_c4', 'B2_c5', 'B2_c6', 'B2_c7',
       'B2_d1', 'B2_d2', 'B2_d3', 'B2_d4', 'B2_d5', 'B2_d6', 'B2_d7', 'B2_d8',
       'B2_d9', 'B3', 'B4_a2', 'B4_a5', 'B5_a2', 'B5_a3', 'B6']
X_old = data[features]

X = X_old
X = StandardScaler().fit_transform(X_old)
X = MinMaxScaler().fit_transform(X_old)

# %%
sampling_strategy = {0: 76, 1: 76}
undersample = RandomUnderSampler(sampling_strategy=sampling_strategy)

X, y = undersample.fit_resample(X, y)

# Transform the dataset using SMOTE
# oversample = SMOTE()
# X, y = oversample.fit_resample(X, y)

# %%
# Summarise the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 76, 1: 76})

# %%
# HOLDOUT METHOD:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 1)

# Logistic Regression

log_model = LogisticRegression()
log_model.fit(X_train, y_train)
print("Logistic Regression:", log_model.score(X_test, y_test).round(3))

# Linear Discriminant Analysis

lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X_train, y_train)
print("Linear Discriminant Analysis:", lda_model.score(X_test, y_test).round(3))

# K-Nearest Neigbors

knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
print("K-Nearest Neigbors:", knn_model.score(X_test, y_test).round(3))

# Classification and Regression Trees

cart_model = DecisionTreeClassifier()
cart_model.fit(X_train, y_train)
print("Classification and Regression Trees:", cart_model.score(X_test, y_test).round(3))

# Gaussian Naive Bayes

gnb_model = GaussianNB()
gnb_model.fit(X_train, y_train)
print("Gaussian Naive Bayes:", gnb_model.score(X_test, y_test).round(3))

# Support Vector Machines

svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X_train, y_train)
print("Support Vector Machines:", svm_model.score(X_test, y_test).round(3))

# Random Forest Classifier

rfc_model = RandomForestClassifier()
rfc_model.fit(X_train, y_train)
print("Random Forest Classifier:", rfc_model.score(X_test, y_test).round(3))
# Out:
# Logistic Regression: 0.754
# Linear Discriminant Analysis: 0.689
# K-Nearest Neigbors: 0.738
# Classification and Regression Trees: 0.541
# Gaussian Naive Bayes: 0.787
# Support Vector Machines: 0.721
# Random Forest Classifier: 0.754

# %%
# Calculating Performance Metrics for Holdout

# %%
# Calculating for Logistic Regression
log_pred = log_model.predict(X_test)

print('Performance Metrics for Logistic Regression:\n')
print(accuracy_score(y_test, log_pred).round(5), '\n')
print(confusion_matrix(y_test, log_pred), '\n')
print(classification_report(y_test, log_pred))
# Out:
# Performance Metrics for Logistic Regression:
#
# 0.7541
#
# [[22  8]
#  [ 7 24]]
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.73      0.75        30
#            1       0.75      0.77      0.76        31
#
#     accuracy                           0.75        61
#    macro avg       0.75      0.75      0.75        61
# weighted avg       0.75      0.75      0.75        61

# %%
# Calculating for LDA
lda_pred = lda_model.predict(X_test)

print('Performance Metrics for LDA:\n')
print(accuracy_score(y_test, lda_pred).round(5), '\n')
print(confusion_matrix(y_test, lda_pred), '\n')
print(classification_report(y_test, lda_pred))
# Out:
# Performance Metrics for LDA:
#
# 0.68852
#
# [[19 11]
#  [ 8 23]]
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.63      0.67        30
#            1       0.68      0.74      0.71        31
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.69      0.69        61
# weighted avg       0.69      0.69      0.69        61

# %%
# Calculating for kNN
knn_pred = knn_model.predict(X_test)

print('Performance Metrics for KNN:\n')
print(accuracy_score(y_test, knn_pred).round(5), '\n')
print(confusion_matrix(y_test, knn_pred), '\n')
print(classification_report(y_test, knn_pred))
# Out:
# Performance Metrics for KNN:
#
# 0.7377
#
# [[24  6]
#  [10 21]]
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.80      0.75        30
#            1       0.78      0.68      0.72        31
#
#     accuracy                           0.74        61
#    macro avg       0.74      0.74      0.74        61
# weighted avg       0.74      0.74      0.74        61

# %%
# Calculating for CART
cart_pred = cart_model.predict(X_test)

print('Performance Metrics for CART:\n')
print(accuracy_score(y_test, cart_pred).round(5), '\n')
print(confusion_matrix(y_test, cart_pred), '\n')
print(classification_report(y_test, cart_pred))
# Out:
# Performance Metrics for CART:
#
# 0.54098
#
# [[16 14]
#  [14 17]]
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.53      0.53        30
#            1       0.55      0.55      0.55        31
#
#     accuracy                           0.54        61
#    macro avg       0.54      0.54      0.54        61
# weighted avg       0.54      0.54      0.54        61

# %%
# Calculating for GNB
gnb_pred = log_model.predict(X_test)

print('Performance Metrics for GNB:\n')
print(accuracy_score(y_test, gnb_pred).round(5), '\n')
print(confusion_matrix(y_test, gnb_pred), '\n')
print(classification_report(y_test, gnb_pred))
# Out:
# Performance Metrics for GNB:
#
# 0.7541
#
# [[22  8]
#  [ 7 24]]
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.73      0.75        30
#            1       0.75      0.77      0.76        31
#
#     accuracy                           0.75        61
#    macro avg       0.75      0.75      0.75        61
# weighted avg       0.75      0.75      0.75        61

# %%
# Calculating for Support Vector Machine
svm_pred = svm_model.predict(X_test)

print('Performance Metrics for SVM:\n')
print(accuracy_score(y_test, svm_pred).round(5), '\n')
print(confusion_matrix(y_test, svm_pred), '\n')
print(classification_report(y_test, svm_pred))
# Out:
# Performance Metrics for SVM:
#
# 0.72131
#
# [[22  8]
#  [ 9 22]]
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72        30
#            1       0.73      0.71      0.72        31
#
#     accuracy                           0.72        61
#    macro avg       0.72      0.72      0.72        61
# weighted avg       0.72      0.72      0.72        61

# %%
# Calculating for Random Forest Classifier
rfc_pred = rfc_model.predict(X_test)

print('Performance Metrics for RFC:\n')
print(accuracy_score(y_test, rfc_pred).round(5), '\n')
print(confusion_matrix(y_test, rfc_pred), '\n')
print(classification_report(y_test, rfc_pred))
# Out:
# Performance Metrics for RFC:
#
# 0.7541
#
# [[24  6]
#  [ 9 22]]
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        30
#            1       0.79      0.71      0.75        31
#
#     accuracy                           0.75        61
#    macro avg       0.76      0.75      0.75        61
# weighted avg       0.76      0.75      0.75        61

# %%
# Obtain the top features from the classification results

# Logistic Regression

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(log_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# Haemoglobin (g/L)                         1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# ALT                                       1
# Creatinine (umol/L)                       1
# Chloride (mmol/L)                         1
# Monocytes (/L)                            1
# pH                                        2
# Glucose (mmol/L)                          3
# Potassium (mmol/L)                        4
# Vitamin B12 (pmol/L)                      5
# Uric Acid (mmol/L)                        6
# Triglyceride (mmol/L)                     7
# Lymphocytes (/L)                          8
# Alkaline Phosphatase (U/L)                9
# C-Reactive Protein                       10
# Urea (mmol/L)                            11
# Free Tri-iodothyronine (FT3) (pmol/L)    12
# RDW (%)                                  13
# Total Bilirubin (µmol/L)                 14
# Neutrophils (/L)                         15
# Thyroid Stimulating Hormone (mIU/L)      16
# Total Cholesterol/HDL Ratio              17
# Phosphate (mmol/L)                       18
# HDL Cholesterol (mmol/L)                 19
# GGT                                      20
# MCH (pg)                                 21
# HbA1c                                    22
# S.G.                                     23
# Albumin (g/L)                            24
# Globulin (g/L)                           25
# Calcium (mmol/L)                         26
# White Cell Count (/L)                    27
# MCV (fL)                                 28
# Total Cholesterol (mmol/L)               29
# MCHC (g/L)                               30
# Corrected Calcium (mmol/L)               31
# Total Protein (g/L)                      32
# LDL Cholesterol (mmol/L)                 33
# Platelets (/L)                           34
# 25-hydroxy Vitamin D (nmol/L)            35
# AST                                      36
# Albumin/Globulin ratio                   37

# %%
# Linear Discriminant Analysis

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(lda_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Vitamin B12 (pmol/L)                      1
# Alkaline Phosphatase (U/L)                1
# Neutrophils (/L)                          1
# White Cell Count (/L)                     1
# GGT                                       1
# MCH (pg)                                  1
# Platelets (/L)                            1
# RBC (/L)                                  1
# C-Reactive Protein                        1
# Serum Homocysteine (µmol/L)               1
# MCHC (g/L)                                2
# Total Bilirubin (µmol/L)                  3
# Urea (mmol/L)                             4
# Glucose (mmol/L)                          5
# Chloride (mmol/L)                         6
# PCV (L/L)                                 7
# Calcium (mmol/L)                          8
# Corrected Calcium (mmol/L)                9
# Albumin/Globulin ratio                   10
# Total Protein (g/L)                      11
# LDL Cholesterol (mmol/L)                 12
# Phosphate (mmol/L)                       13
# Uric Acid (mmol/L)                       14
# HDL Cholesterol (mmol/L)                 15
# Albumin (g/L)                            16
# Triglyceride (mmol/L)                    17
# Total Cholesterol (mmol/L)               18
# Total Cholesterol/HDL Ratio              19
# ALT                                      20
# Haemoglobin (g/L)                        21
# Serum Folate (nmol/L)                    22
# Sodium (mmol/L)                          23
# S.G.                                     24
# Free Tri-iodothyronine (FT3) (pmol/L)    25
# pH                                       26
# MCV (fL)                                 27
# Monocytes (/L)                           28
# Creatinine (umol/L)                      29
# AST                                      30
# 25-hydroxy Vitamin D (nmol/L)            31
# Potassium (mmol/L)                       32
# Lymphocytes (/L)                         33
# Thyroid Stimulating Hormone (mIU/L)      34
# Globulin (g/L)                           35
# HbA1c                                    36
# RDW (%)                                  37

# %%
# Classification and Regression Trees

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(cart_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Total Bilirubin (µmol/L)                  1
# Alkaline Phosphatase (U/L)                1
# Glucose (mmol/L)                          1
# Albumin (g/L)                             1
# Globulin (g/L)                            1
# Neutrophils (/L)                          1
# GGT                                       1
# White Cell Count (/L)                     1
# PCV (L/L)                                 1
# Serum Homocysteine (µmol/L)               1
# Total Protein (g/L)                       2
# Phosphate (mmol/L)                        3
# Albumin/Globulin ratio                    4
# RDW (%)                                   5
# MCHC (g/L)                                6
# MCV (fL)                                  7
# RBC (/L)                                  8
# MCH (pg)                                  9
# 25-hydroxy Vitamin D (nmol/L)            10
# Haemoglobin (g/L)                        11
# AST                                      12
# ALT                                      13
# C-Reactive Protein                       14
# Lymphocytes (/L)                         15
# pH                                       16
# Monocytes (/L)                           17
# S.G.                                     18
# Thyroid Stimulating Hormone (mIU/L)      19
# Free Tri-iodothyronine (FT3) (pmol/L)    20
# Total Cholesterol (mmol/L)               21
# Corrected Calcium (mmol/L)               22
# Triglyceride (mmol/L)                    23
# Calcium (mmol/L)                         24
# HDL Cholesterol (mmol/L)                 25
# Uric Acid (mmol/L)                       26
# Platelets (/L)                           27
# Creatinine (umol/L)                      28
# LDL Cholesterol (mmol/L)                 29
# Urea (mmol/L)                            30
# Total Cholesterol/HDL Ratio              31
# Chloride (mmol/L)                        32
# Sodium (mmol/L)                          33
# HbA1c                                    34
# Serum Folate (nmol/L)                    35
# Potassium (mmol/L)                       36
# Vitamin B12 (pmol/L)                     37

# %%
# Support Vector Machines

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(svm_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Homocysteine (µmol/L)               1
# ALT                                       1
# Creatinine (umol/L)                       1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# Chloride (mmol/L)                         1
# Potassium (mmol/L)                        1
# Glucose (mmol/L)                          1
# Monocytes (/L)                            1
# pH                                        2
# Vitamin B12 (pmol/L)                      3
# Triglyceride (mmol/L)                     4
# Serum Folate (nmol/L)                     5
# Haemoglobin (g/L)                         6
# Uric Acid (mmol/L)                        7
# Free Tri-iodothyronine (FT3) (pmol/L)     8
# C-Reactive Protein                        9
# GGT                                      10
# Alkaline Phosphatase (U/L)               11
# RDW (%)                                  12
# Neutrophils (/L)                         13
# S.G.                                     14
# Total Bilirubin (µmol/L)                 15
# Thyroid Stimulating Hormone (mIU/L)      16
# Platelets (/L)                           17
# Lymphocytes (/L)                         18
# Globulin (g/L)                           19
# 25-hydroxy Vitamin D (nmol/L)            20
# MCHC (g/L)                               21
# Total Protein (g/L)                      22
# Corrected Calcium (mmol/L)               23
# Urea (mmol/L)                            24
# White Cell Count (/L)                    25
# MCH (pg)                                 26
# Albumin/Globulin ratio                   27
# HbA1c                                    28
# LDL Cholesterol (mmol/L)                 29
# Total Cholesterol (mmol/L)               30
# MCV (fL)                                 31
# AST                                      32
# Albumin (g/L)                            33
# Calcium (mmol/L)                         34
# HDL Cholesterol (mmol/L)                 35
# Total Cholesterol/HDL Ratio              36
# Phosphate (mmol/L)                       37

# %%
# Random Forest Classifier

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(rfc_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Potassium (mmol/L)                        1
# Glucose (mmol/L)                          1
# Neutrophils (/L)                          1
# White Cell Count (/L)                     1
# PCV (L/L)                                 1
# LDL Cholesterol (mmol/L)                  1
# Haemoglobin (g/L)                         1
# Serum Homocysteine (µmol/L)               1
# Serum Folate (nmol/L)                     1
# RBC (/L)                                  1
# Chloride (mmol/L)                         2
# ALT                                       3
# Monocytes (/L)                            4
# Alkaline Phosphatase (U/L)                5
# HDL Cholesterol (mmol/L)                  6
# Platelets (/L)                            7
# Sodium (mmol/L)                           8
# Total Cholesterol (mmol/L)                9
# C-Reactive Protein                       10
# Total Cholesterol/HDL Ratio              11
# Lymphocytes (/L)                         12
# Vitamin B12 (pmol/L)                     13
# Creatinine (umol/L)                      14
# Triglyceride (mmol/L)                    15
# 25-hydroxy Vitamin D (nmol/L)            16
# RDW (%)                                  17
# Globulin (g/L)                           18
# Albumin (g/L)                            19
# S.G.                                     20
# Uric Acid (mmol/L)                       21
# Albumin/Globulin ratio                   22
# Free Tri-iodothyronine (FT3) (pmol/L)    23
# Urea (mmol/L)                            24
# AST                                      25
# Calcium (mmol/L)                         26
# GGT                                      27
# MCV (fL)                                 28
# Phosphate (mmol/L)                       29
# Thyroid Stimulating Hormone (mIU/L)      30
# pH                                       31
# Total Protein (g/L)                      32
# Corrected Calcium (mmol/L)               33
# Total Bilirubin (µmol/L)                 34
# MCHC (g/L)                               35
# HbA1c                                    36
# MCH (pg)                                 37

# %%
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedStratifiedKFold
import matplotlib.pyplot as plt

# get a list of models to evaluate
def get_models():
    models = dict()
    # Logistic Regression
    rfe = RFE(log_model, 10)
    model = DecisionTreeClassifier()
    models['LOG'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Linear Discriminant Analysis
    rfe = RFE(lda_model, 10)
    model = DecisionTreeClassifier()
    models['LDA'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Classification & Regression Trees
    rfe = RFE(cart_model, 10)
    model = DecisionTreeClassifier()
    models['CART'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Support Vector Machines
    rfe = RFE(svm_model, 10)
    model = DecisionTreeClassifier()
    models['SVM'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Random Forest Classifier
    rfe = RFE(rfc_model, 10)
    model = DecisionTreeClassifier()
    models['RFC'] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    return scores

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X_train, y_train)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# >LOG 0.635 (0.139)
# >LDA 0.604 (0.195)
# >CART 0.557 (0.194)
# >SVM 0.601 (0.153)
# >RFC 0.575 (0.165)

# %%
# CROSS-VALIDATION:

# %%
# Logistic Regression

log_model = LogisticRegression()
log_model.fit(X, y)
scores = cross_val_score(log_model, X, y, cv=5)
print("Logistic Regression: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Linear Discriminant Analysis

lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X, y)
scores = cross_val_score(lda_model, X, y, cv=5)
print("Linear Discriminant Analysis: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# K-Nearest Neigbors

knn_model = KNeighborsClassifier()
knn_model.fit(X, y)
scores = cross_val_score(knn_model, X, y, cv=5)
print("K-Nearest Neighbors: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Classification and Regression Trees

cart_model = DecisionTreeClassifier()
cart_model.fit(X, y)
scores = cross_val_score(cart_model, X, y, cv=5)
print("Classification and Regression Trees: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Gaussian Naive Bayes

gnb_model = GaussianNB()
gnb_model.fit(X, y)
scores = cross_val_score(gnb_model, X, y, cv=5)
print("Gaussian Naive Bayes: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Support Vector Machines

svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X, y)
scores = cross_val_score(svm_model, X, y, cv=5)
print("Support Vector Machines: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Random Forest Classifier

rfc_model = RandomForestClassifier()
rfc_model.fit(X, y)
scores = cross_val_score(rfc_model, X, y, cv=5)
print("Random Forest Classifier: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))
# Out:
# Logistic Regression: 0.703 accuracy with a standard deviation of 0.065
# Linear Discriminant Analysis: 0.664 accuracy with a standard deviation of 0.048
# K-Nearest Neighbors: 0.618 accuracy with a standard deviation of 0.044
# Classification and Regression Trees: 0.578 accuracy with a standard deviation of 0.112
# Gaussian Naive Bayes: 0.737 accuracy with a standard deviation of 0.024
# Support Vector Machines: 0.736 accuracy with a standard deviation of 0.080
# Random Forest Classifier: 0.685 accuracy with a standard deviation of 0.058

# %%
# Producing Cross-Validation Classification Reports for each Algorithm

# %%
# Logistic Regression
scores = cross_val_score(log_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73        16
#            1       0.71      0.67      0.69        15
#
#     accuracy                           0.71        31
#    macro avg       0.71      0.71      0.71        31
# weighted avg       0.71      0.71      0.71        31
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77        15
#            1       0.80      0.75      0.77        16
#
#     accuracy                           0.77        31
#    macro avg       0.78      0.78      0.77        31
# weighted avg       0.78      0.77      0.77        31
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76        15
#            1       0.75      0.80      0.77        15
#
#     accuracy                           0.77        30
#    macro avg       0.77      0.77      0.77        30
# weighted avg       0.77      0.77      0.77        30
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.73      0.65        15
#            1       0.64      0.47      0.54        15
#
#     accuracy                           0.60        30
#    macro avg       0.61      0.60      0.59        30
# weighted avg       0.61      0.60      0.59        30
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        15
#            1       0.67      0.67      0.67        15
#
#     accuracy                           0.67        30
#    macro avg       0.67      0.67      0.67        30
# weighted avg       0.67      0.67      0.67        30
#
# [0.70967742 0.77419355 0.76666667 0.6        0.66666667]

# %%
# Linear Discriminant Analysis
scores = cross_val_score(lda_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71        16
#            1       0.69      0.60      0.64        15
#
#     accuracy                           0.68        31
#    macro avg       0.68      0.68      0.67        31
# weighted avg       0.68      0.68      0.68        31
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.71        15
#            1       0.72      0.81      0.76        16
#
#     accuracy                           0.74        31
#    macro avg       0.75      0.74      0.74        31
# weighted avg       0.74      0.74      0.74        31
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.47      0.54        15
#            1       0.58      0.73      0.65        15
#
#     accuracy                           0.60        30
#    macro avg       0.61      0.60      0.59        30
# weighted avg       0.61      0.60      0.59        30
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.73      0.67        15
#            1       0.67      0.53      0.59        15
#
#     accuracy                           0.63        30
#    macro avg       0.64      0.63      0.63        30
# weighted avg       0.64      0.63      0.63        30
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        15
#            1       0.67      0.67      0.67        15
#
#     accuracy                           0.67        30
#    macro avg       0.67      0.67      0.67        30
# weighted avg       0.67      0.67      0.67        30
#
# [0.67741935 0.74193548 0.6        0.63333333 0.66666667]

# %%
# K-Nearest Neigbors
knn_model = KNeighborsClassifier()
knn_model.fit(X, y)
scores = cross_val_score(knn_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.88      0.74        16
#            1       0.78      0.47      0.58        15
#
#     accuracy                           0.68        31
#    macro avg       0.71      0.67      0.66        31
# weighted avg       0.70      0.68      0.66        31
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.93      0.72        15
#            1       0.86      0.38      0.52        16
#
#     accuracy                           0.65        31
#    macro avg       0.72      0.65      0.62        31
# weighted avg       0.72      0.65      0.62        31
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.80      0.65        15
#            1       0.62      0.33      0.43        15
#
#     accuracy                           0.57        30
#    macro avg       0.59      0.57      0.54        30
# weighted avg       0.59      0.57      0.54        30
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.93      0.72        15
#            1       0.83      0.33      0.48        15
#
#     accuracy                           0.63        30
#    macro avg       0.71      0.63      0.60        30
# weighted avg       0.71      0.63      0.60        30
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58        15
#            1       0.57      0.53      0.55        15
#
#     accuracy                           0.57        30
#    macro avg       0.57      0.57      0.57        30
# weighted avg       0.57      0.57      0.57        30
#
# [0.67741935 0.64516129 0.56666667 0.63333333 0.56666667]

# %%
# Classification and Regression Trees
cart_model = DecisionTreeClassifier()
cart_model.fit(X, y)
scores = cross_val_score(cart_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.81      0.76        16
#            1       0.77      0.67      0.71        15
#
#     accuracy                           0.74        31
#    macro avg       0.75      0.74      0.74        31
# weighted avg       0.74      0.74      0.74        31
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.53      0.57        15
#            1       0.61      0.69      0.65        16
#
#     accuracy                           0.61        31
#    macro avg       0.61      0.61      0.61        31
# weighted avg       0.61      0.61      0.61        31
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.47      0.50        15
#            1       0.53      0.60      0.56        15
#
#     accuracy                           0.53        30
#    macro avg       0.53      0.53      0.53        30
# weighted avg       0.53      0.53      0.53        30
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.80      0.75        15
#            1       0.77      0.67      0.71        15
#
#     accuracy                           0.73        30
#    macro avg       0.74      0.73      0.73        30
# weighted avg       0.74      0.73      0.73        30
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        15
#            1       0.60      0.60      0.60        15
#
#     accuracy                           0.60        30
#    macro avg       0.60      0.60      0.60        30
# weighted avg       0.60      0.60      0.60        30
#
# [0.74193548 0.61290323 0.53333333 0.73333333 0.6       ]

# %%
# Gaussian Naive Bayes
gnb_model = GaussianNB()
gnb_model.fit(X, y)
scores = cross_val_score(gnb_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.88      0.78        16
#            1       0.82      0.60      0.69        15
#
#     accuracy                           0.74        31
#    macro avg       0.76      0.74      0.74        31
# weighted avg       0.76      0.74      0.74        31
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79        15
#            1       0.85      0.69      0.76        16
#
#     accuracy                           0.77        31
#    macro avg       0.78      0.78      0.77        31
# weighted avg       0.79      0.77      0.77        31
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        15
#            1       0.75      0.60      0.67        15
#
#     accuracy                           0.70        30
#    macro avg       0.71      0.70      0.70        30
# weighted avg       0.71      0.70      0.70        30
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.87      0.76        15
#            1       0.82      0.60      0.69        15
#
#     accuracy                           0.73        30
#    macro avg       0.75      0.73      0.73        30
# weighted avg       0.75      0.73      0.73        30
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.80      0.75        15
#            1       0.77      0.67      0.71        15
#
#     accuracy                           0.73        30
#    macro avg       0.74      0.73      0.73        30
# weighted avg       0.74      0.73      0.73        30
#
# [0.74193548 0.77419355 0.7        0.73333333 0.73333333]

# %%
# Support Vector Machines
svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X, y)
scores = cross_val_score(svm_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.81      0.74        16
#            1       0.75      0.60      0.67        15
#
#     accuracy                           0.71        31
#    macro avg       0.72      0.71      0.70        31
# weighted avg       0.72      0.71      0.71        31
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        15
#            1       0.88      0.88      0.88        16
#
#     accuracy                           0.87        31
#    macro avg       0.87      0.87      0.87        31
# weighted avg       0.87      0.87      0.87        31
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76        15
#            1       0.75      0.80      0.77        15
#
#     accuracy                           0.77        30
#    macro avg       0.77      0.77      0.77        30
# weighted avg       0.77      0.77      0.77        30
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.73      0.67        15
#            1       0.67      0.53      0.59        15
#
#     accuracy                           0.63        30
#    macro avg       0.64      0.63      0.63        30
# weighted avg       0.64      0.63      0.63        30
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71        15
#            1       0.71      0.67      0.69        15
#
#     accuracy                           0.70        30
#    macro avg       0.70      0.70      0.70        30
# weighted avg       0.70      0.70      0.70        30
#
# [0.70967742 0.87096774 0.76666667 0.63333333 0.7       ]

# %%
# Random Forest Classifier
rfc_model = RandomForestClassifier()
rfc_model.fit(X, y)
scores = cross_val_score(rfc_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        16
#            1       0.73      0.73      0.73        15
#
#     accuracy                           0.74        31
#    macro avg       0.74      0.74      0.74        31
# weighted avg       0.74      0.74      0.74        31
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.87      0.76        15
#            1       0.83      0.62      0.71        16
#
#     accuracy                           0.74        31
#    macro avg       0.76      0.75      0.74        31
# weighted avg       0.76      0.74      0.74        31
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77        15
#            1       0.79      0.73      0.76        15
#
#     accuracy                           0.77        30
#    macro avg       0.77      0.77      0.77        30
# weighted avg       0.77      0.77      0.77        30
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        15
#            1       0.67      0.67      0.67        15
#
#     accuracy                           0.67        30
#    macro avg       0.67      0.67      0.67        30
# weighted avg       0.67      0.67      0.67        30
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.71        15
#            1       0.71      0.80      0.75        15
#
#     accuracy                           0.73        30
#    macro avg       0.74      0.73      0.73        30
# weighted avg       0.74      0.73      0.73        30
#
# [0.74193548 0.74193548 0.76666667 0.66666667 0.73333333]

# %%
# Logistic Regression

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(log_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# Haemoglobin (g/L)                         1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# ALT                                       1
# Creatinine (umol/L)                       1
# Chloride (mmol/L)                         1
# Monocytes (/L)                            1
# pH                                        2
# Glucose (mmol/L)                          3
# Potassium (mmol/L)                        4
# Vitamin B12 (pmol/L)                      5
# Uric Acid (mmol/L)                        6
# Triglyceride (mmol/L)                     7
# Lymphocytes (/L)                          8
# Alkaline Phosphatase (U/L)                9
# C-Reactive Protein                       10
# Urea (mmol/L)                            11
# Free Tri-iodothyronine (FT3) (pmol/L)    12
# RDW (%)                                  13
# Total Bilirubin (µmol/L)                 14
# Neutrophils (/L)                         15
# Thyroid Stimulating Hormone (mIU/L)      16
# Total Cholesterol/HDL Ratio              17
# Phosphate (mmol/L)                       18
# HDL Cholesterol (mmol/L)                 19
# GGT                                      20
# MCH (pg)                                 21
# HbA1c                                    22
# S.G.                                     23
# Albumin (g/L)                            24
# Globulin (g/L)                           25
# Calcium (mmol/L)                         26
# White Cell Count (/L)                    27
# MCV (fL)                                 28
# Total Cholesterol (mmol/L)               29
# MCHC (g/L)                               30
# Corrected Calcium (mmol/L)               31
# Total Protein (g/L)                      32
# LDL Cholesterol (mmol/L)                 33
# Platelets (/L)                           34
# 25-hydroxy Vitamin D (nmol/L)            35
# AST                                      36
# Albumin/Globulin ratio                   37

# %%
# Linear Discriminant Analysis

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(lda_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Vitamin B12 (pmol/L)                      1
# Alkaline Phosphatase (U/L)                1
# Neutrophils (/L)                          1
# White Cell Count (/L)                     1
# GGT                                       1
# MCH (pg)                                  1
# Platelets (/L)                            1
# RBC (/L)                                  1
# C-Reactive Protein                        1
# Serum Homocysteine (µmol/L)               1
# MCHC (g/L)                                2
# Total Bilirubin (µmol/L)                  3
# Urea (mmol/L)                             4
# Glucose (mmol/L)                          5
# Chloride (mmol/L)                         6
# PCV (L/L)                                 7
# Calcium (mmol/L)                          8
# Corrected Calcium (mmol/L)                9
# Albumin/Globulin ratio                   10
# Total Protein (g/L)                      11
# LDL Cholesterol (mmol/L)                 12
# Phosphate (mmol/L)                       13
# Uric Acid (mmol/L)                       14
# HDL Cholesterol (mmol/L)                 15
# Albumin (g/L)                            16
# Triglyceride (mmol/L)                    17
# Total Cholesterol (mmol/L)               18
# Total Cholesterol/HDL Ratio              19
# ALT                                      20
# Haemoglobin (g/L)                        21
# Serum Folate (nmol/L)                    22
# Sodium (mmol/L)                          23
# S.G.                                     24
# Free Tri-iodothyronine (FT3) (pmol/L)    25
# pH                                       26
# MCV (fL)                                 27
# Monocytes (/L)                           28
# Creatinine (umol/L)                      29
# AST                                      30
# 25-hydroxy Vitamin D (nmol/L)            31
# Potassium (mmol/L)                       32
# Lymphocytes (/L)                         33
# Thyroid Stimulating Hormone (mIU/L)      34
# Globulin (g/L)                           35
# HbA1c                                    36
# RDW (%)                                  37

# %%
# Classification and Regression Trees

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(cart_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# LDL Cholesterol (mmol/L)                  1
# Total Protein (g/L)                       1
# Alkaline Phosphatase (U/L)                1
# Globulin (g/L)                            1
# Glucose (mmol/L)                          1
# Neutrophils (/L)                          1
# White Cell Count (/L)                     1
# Albumin/Globulin ratio                    1
# PCV (L/L)                                 1
# Serum Homocysteine (µmol/L)               1
# Uric Acid (mmol/L)                        2
# Calcium (mmol/L)                          3
# Corrected Calcium (mmol/L)                4
# Creatinine (umol/L)                       5
# MCHC (g/L)                                6
# RDW (%)                                   7
# Urea (mmol/L)                             8
# MCV (fL)                                  9
# MCH (pg)                                 10
# RBC (/L)                                 11
# Haemoglobin (g/L)                        12
# Albumin (g/L)                            13
# Phosphate (mmol/L)                       14
# HDL Cholesterol (mmol/L)                 15
# Monocytes (/L)                           16
# 25-hydroxy Vitamin D (nmol/L)            17
# Lymphocytes (/L)                         18
# Platelets (/L)                           19
# Total Bilirubin (µmol/L)                 20
# GGT                                      21
# Triglyceride (mmol/L)                    22
# Total Cholesterol (mmol/L)               23
# AST                                      24
# ALT                                      25
# C-Reactive Protein                       26
# pH                                       27
# S.G.                                     28
# Thyroid Stimulating Hormone (mIU/L)      29
# Total Cholesterol/HDL Ratio              30
# Free Tri-iodothyronine (FT3) (pmol/L)    31
# Chloride (mmol/L)                        32
# Sodium (mmol/L)                          33
# HbA1c                                    34
# Potassium (mmol/L)                       35
# Serum Folate (nmol/L)                    36
# Vitamin B12 (pmol/L)                     37

# %%
# Support Vector Machines

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(svm_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Homocysteine (µmol/L)               1
# ALT                                       1
# Creatinine (umol/L)                       1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# Chloride (mmol/L)                         1
# Potassium (mmol/L)                        1
# Glucose (mmol/L)                          1
# Monocytes (/L)                            1
# pH                                        2
# Vitamin B12 (pmol/L)                      3
# Triglyceride (mmol/L)                     4
# Serum Folate (nmol/L)                     5
# Haemoglobin (g/L)                         6
# Uric Acid (mmol/L)                        7
# Free Tri-iodothyronine (FT3) (pmol/L)     8
# C-Reactive Protein                        9
# GGT                                      10
# Alkaline Phosphatase (U/L)               11
# RDW (%)                                  12
# Neutrophils (/L)                         13
# S.G.                                     14
# Total Bilirubin (µmol/L)                 15
# Thyroid Stimulating Hormone (mIU/L)      16
# Platelets (/L)                           17
# Lymphocytes (/L)                         18
# Globulin (g/L)                           19
# 25-hydroxy Vitamin D (nmol/L)            20
# MCHC (g/L)                               21
# Total Protein (g/L)                      22
# Corrected Calcium (mmol/L)               23
# Urea (mmol/L)                            24
# White Cell Count (/L)                    25
# MCH (pg)                                 26
# Albumin/Globulin ratio                   27
# HbA1c                                    28
# LDL Cholesterol (mmol/L)                 29
# Total Cholesterol (mmol/L)               30
# MCV (fL)                                 31
# AST                                      32
# Albumin (g/L)                            33
# Calcium (mmol/L)                         34
# HDL Cholesterol (mmol/L)                 35
# Total Cholesterol/HDL Ratio              36
# Phosphate (mmol/L)                       37

# %%
# Random Forest Classifier

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(rfc_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Alkaline Phosphatase (U/L)                1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# Chloride (mmol/L)                         1
# Haemoglobin (g/L)                         1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# Potassium (mmol/L)                        1
# Glucose (mmol/L)                          1
# Neutrophils (/L)                          1
# White Cell Count (/L)                     2
# ALT                                       3
# C-Reactive Protein                        4
# Monocytes (/L)                            5
# HDL Cholesterol (mmol/L)                  6
# Vitamin B12 (pmol/L)                      7
# RDW (%)                                   8
# Creatinine (umol/L)                       9
# 25-hydroxy Vitamin D (nmol/L)            10
# Calcium (mmol/L)                         11
# Sodium (mmol/L)                          12
# Platelets (/L)                           13
# LDL Cholesterol (mmol/L)                 14
# Total Cholesterol (mmol/L)               15
# HbA1c                                    16
# Triglyceride (mmol/L)                    17
# Free Tri-iodothyronine (FT3) (pmol/L)    18
# Urea (mmol/L)                            19
# Total Cholesterol/HDL Ratio              20
# GGT                                      21
# MCHC (g/L)                               22
# Phosphate (mmol/L)                       23
# Albumin (g/L)                            24
# Lymphocytes (/L)                         25
# Uric Acid (mmol/L)                       26
# MCV (fL)                                 27
# S.G.                                     28
# Thyroid Stimulating Hormone (mIU/L)      29
# Globulin (g/L)                           30
# Albumin/Globulin ratio                   31
# Total Bilirubin (µmol/L)                 32
# Total Protein (g/L)                      33
# Corrected Calcium (mmol/L)               34
# AST                                      35
# pH                                       36
# MCH (pg)                                 37

# %%
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedStratifiedKFold
import matplotlib.pyplot as plt

# get a list of models to evaluate
def get_models():
    models = dict()
    # Logistic Regression
    rfe = RFE(log_model, 10)
    model = DecisionTreeClassifier()
    models['LOG'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Linear Discriminant Analysis
    rfe = RFE(lda_model, 10)
    model = DecisionTreeClassifier()
    models['LDA'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Classification & Regression Trees
    rfe = RFE(cart_model, 10)
    model = DecisionTreeClassifier()
    models['CART'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Support Vector Machines
    rfe = RFE(svm_model, 10)
    model = DecisionTreeClassifier()
    models['SVM'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Random Forest Classifier
    rfe = RFE(rfc_model, 10)
    model = DecisionTreeClassifier()
    models['RFC'] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    return scores

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X_train, y_train)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# >LOG 0.631 (0.138)
# >LDA 0.600 (0.200)
# >CART 0.568 (0.203)
# >SVM 0.608 (0.170)
# >RFC 0.579 (0.179)

# %%
# Test 6: Using New Dataset, 343 Robust and Frail+MCI SMOTEd to 343

# %%
# Pre-parse the dataset
data = RobustFrailMCIpreprocess("rawfile_robust_frailmci.csv")
# Out:
# robust       368
# frail_mci     86
# Name: condition, dtype: int64
#
# ####################################################################
# Number of Rows of Dataframe:
# 454
# Number of Columns of Dataframe:
# 59
#
# ####################################################################
# Threshold for number of NULLs in a column: 0.1095
# Number of Columns before Parsing for Too Many NULLs in a column:
# 59
# Number of Columns after Parsing for Too Many NULLs in a column:
# 51
#
# Columns Removed:
# B1_b5
# B4_a1
# B4_a3
# B4_a4
# B4_a6
# B4_b1
# B4_b3
# B5_a1
#
# ####################################################################
# Number of Columns after dropping B1_b4, B2_c3, B4_b2 for inconsistent data types:
# 48
#
# ####################################################################
# Number of Rows before Parsing NULLs in data:
# 454
# Number of Rows after Parsing NULLs in data:
# 419

# %%
# Taking only Frail+MCI and Robust classes

df1 = data[data.condition == 'frail_mci']
df1 = df1.reset_index(drop=True)

df2 = data[data.condition == 'robust']
df2 = df2.reset_index(drop=True)

data = pd.concat([df1, df2], ignore_index=True)

# %%
data.head()
# Out:
#       mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  ...  \
# 0  ME01378  frail_mci   241  13.0    20  33.5   150   5.25   0.46     87  ...
# 1  ME02832  frail_mci   444  43.8    16  87.0   134   4.65   0.40     85  ...
# 2  ME02909  frail_mci  1476  54.5    16  57.0   119   3.80   0.36     94  ...
# 3  ME02998  frail_mci   339  25.9    18  63.8   135   4.89   0.42     86  ...
# 4  ME03061  frail_mci   287  23.8    20  95.5   146   5.18   0.44     85  ...
#
#    B2_d6  B2_d7  B2_d8  B2_d9    B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 0     10     21     22     17   1.3    7.0  1.010   0.69    4.7  5.9
# 1     10     14     20     15  13.4    6.0  1.005   1.29    4.5  5.8
# 2     18     17     35     21   0.2    7.5  1.012   1.90    4.1  5.8
# 3     13     16     25     13  16.8    5.0  1.017   1.32    4.0  6.0
# 4     18     22     25     24   1.4    7.5  1.006   2.94    4.6  6.1
#
# [5 rows x 48 columns]

# %%
data.tail()
# Out:
#         mtag condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  \
# 414  MV00454    robust   220  24.6    19  67.5   138   4.66   0.42     91
# 415  MV00456    robust   334  20.1    18  51.0   139   4.63   0.42     91
# 416  MV00460    robust   418  54.4    17  61.0   122   4.18   0.38     90
# 417  MV00502    robust   393  38.2    18  43.1   136   4.57   0.43     94
# 418  MV00510    robust   371  23.2    24  55.9   127   4.41   0.40     90
#
#      ...  B2_d6  B2_d7  B2_d8  B2_d9   B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 414  ...     20     10     17      8  6.6    7.0  1.015   1.29    4.5  6.2
# 415  ...     16     22     35     40  1.0    6.0  1.015   1.88    3.9  5.6
# 416  ...     19     20     23     15  0.4    6.5  1.005   3.58    4.0  5.6
# 417  ...     13     11     22     23  0.7    7.0  1.009   0.92    4.1  6.0
# 418  ...     13     14     16     12  7.5    8.0  1.017   2.45    4.5  6.2
#
# [5 rows x 48 columns]

# %%
c = data['condition'].value_counts()
condition = c.index
c
# Out:
# robust       343
# frail_mci     76
# Name: condition, dtype: int64

# %%
for i in range(len(condition)):
    data['condition'].replace(condition[i], i, inplace = True)

data.head()
# Out:
#       mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  ...  \
# 0  ME01378          1   241  13.0    20  33.5   150   5.25   0.46     87  ...
# 1  ME02832          1   444  43.8    16  87.0   134   4.65   0.40     85  ...
# 2  ME02909          1  1476  54.5    16  57.0   119   3.80   0.36     94  ...
# 3  ME02998          1   339  25.9    18  63.8   135   4.89   0.42     86  ...
# 4  ME03061          1   287  23.8    20  95.5   146   5.18   0.44     85  ...
#
#    B2_d6  B2_d7  B2_d8  B2_d9    B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 0     10     21     22     17   1.3    7.0  1.010   0.69    4.7  5.9
# 1     10     14     20     15  13.4    6.0  1.005   1.29    4.5  5.8
# 2     18     17     35     21   0.2    7.5  1.012   1.90    4.1  5.8
# 3     13     16     25     13  16.8    5.0  1.017   1.32    4.0  6.0
# 4     18     22     25     24   1.4    7.5  1.006   2.94    4.6  6.1
#
# [5 rows x 48 columns]

# %%
data.tail()
# Out:
#         mtag  condition  A1_1  A1_2  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  \
# 414  MV00454          0   220  24.6    19  67.5   138   4.66   0.42     91
# 415  MV00456          0   334  20.1    18  51.0   139   4.63   0.42     91
# 416  MV00460          0   418  54.4    17  61.0   122   4.18   0.38     90
# 417  MV00502          0   393  38.2    18  43.1   136   4.57   0.43     94
# 418  MV00510          0   371  23.2    24  55.9   127   4.41   0.40     90
#
#      ...  B2_d6  B2_d7  B2_d8  B2_d9   B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 414  ...     20     10     17      8  6.6    7.0  1.015   1.29    4.5  6.2
# 415  ...     16     22     35     40  1.0    6.0  1.015   1.88    3.9  5.6
# 416  ...     19     20     23     15  0.4    6.5  1.005   3.58    4.0  5.6
# 417  ...     13     11     22     23  0.7    7.0  1.009   0.92    4.1  6.0
# 418  ...     13     14     16     12  7.5    8.0  1.017   2.45    4.5  6.2
#
# [5 rows x 48 columns]

# %%
y = data['condition']

features = ['A1_1', 'A1_2', 'A2_1', 'A3_1', 'B1_a', 'B1_a1', 'B1_a2',
       'B1_a3', 'B1_a4', 'B1_a5', 'B1_a6', 'B1_b', 'B1_b1', 'B1_b2', 'B1_b3',
       'B1_c', 'B1_d', 'B2_a1', 'B2_a2', 'B2_a3', 'B2_a4', 'B2_a5', 'B2_b1',
       'B2_b2', 'B2_b3', 'B2_c1', 'B2_c2', 'B2_c4', 'B2_c5', 'B2_c6', 'B2_c7',
       'B2_d1', 'B2_d2', 'B2_d3', 'B2_d4', 'B2_d5', 'B2_d6', 'B2_d7', 'B2_d8',
       'B2_d9', 'B3', 'B4_a2', 'B4_a5', 'B5_a2', 'B5_a3', 'B6']
X_old = data[features]

X = X_old
X = StandardScaler().fit_transform(X_old)
X = MinMaxScaler().fit_transform(X_old)

# %%
# sampling_strategy = {0: 76, 1: 76}
# undersample = RandomUnderSampler(sampling_strategy=sampling_strategy)

# X, y = undersample.fit_resample(X, y)

# Transform the dataset using SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
# Summarise the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({1: 343, 0: 343})

# %%
# HOLDOUT METHOD:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 1)

# Logistic Regression

log_model = LogisticRegression()
log_model.fit(X_train, y_train)
print("Logistic Regression:", log_model.score(X_test, y_test).round(3))

# Linear Discriminant Analysis

lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X_train, y_train)
print("Linear Discriminant Analysis:", lda_model.score(X_test, y_test).round(3))

# K-Nearest Neigbors

knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
print("K-Nearest Neigbors:", knn_model.score(X_test, y_test).round(3))

# Classification and Regression Trees

cart_model = DecisionTreeClassifier()
cart_model.fit(X_train, y_train)
print("Classification and Regression Trees:", cart_model.score(X_test, y_test).round(3))

# Gaussian Naive Bayes

gnb_model = GaussianNB()
gnb_model.fit(X_train, y_train)
print("Gaussian Naive Bayes:", gnb_model.score(X_test, y_test).round(3))

# Support Vector Machines

svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X_train, y_train)
print("Support Vector Machines:", svm_model.score(X_test, y_test).round(3))

# Random Forest Classifier

rfc_model = RandomForestClassifier()
rfc_model.fit(X_train, y_train)
print("Random Forest Classifier:", rfc_model.score(X_test, y_test).round(3))
# Out:
# Logistic Regression: 0.793
# Linear Discriminant Analysis: 0.811
# K-Nearest Neigbors: 0.796
# Classification and Regression Trees: 0.775
# Gaussian Naive Bayes: 0.709
# Support Vector Machines: 0.804
# Random Forest Classifier: 0.898

# %%
# Calculating Performance Metrics for Holdout

# %%
# Calculating for Logistic Regression
log_pred = log_model.predict(X_test)

print('Performance Metrics for Logistic Regression:\n')
print(accuracy_score(y_test, log_pred).round(5), '\n')
print(confusion_matrix(y_test, log_pred), '\n')
print(classification_report(y_test, log_pred))
# Out:
# Performance Metrics for Logistic Regression:
#
# 0.79273
#
# [[102  29]
#  [ 28 116]]
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78       131
#            1       0.80      0.81      0.80       144
#
#     accuracy                           0.79       275
#    macro avg       0.79      0.79      0.79       275
# weighted avg       0.79      0.79      0.79       275

# %%
# Calculating for LDA
lda_pred = lda_model.predict(X_test)

print('Performance Metrics for LDA:\n')
print(accuracy_score(y_test, lda_pred).round(5), '\n')
print(confusion_matrix(y_test, lda_pred), '\n')
print(classification_report(y_test, lda_pred))
# Out:
# Performance Metrics for LDA:
#
# 0.81091
#
# [[ 99  32]
#  [ 20 124]]
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       131
#            1       0.79      0.86      0.83       144
#
#     accuracy                           0.81       275
#    macro avg       0.81      0.81      0.81       275
# weighted avg       0.81      0.81      0.81       275

# %%
# Calculating for kNN
knn_pred = knn_model.predict(X_test)

print('Performance Metrics for KNN:\n')
print(accuracy_score(y_test, knn_pred).round(5), '\n')
print(confusion_matrix(y_test, knn_pred), '\n')
print(classification_report(y_test, knn_pred))
# Out:
# Performance Metrics for KNN:
#
# 0.79636
#
# [[ 77  54]
#  [  2 142]]
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.59      0.73       131
#            1       0.72      0.99      0.84       144
#
#     accuracy                           0.80       275
#    macro avg       0.85      0.79      0.78       275
# weighted avg       0.84      0.80      0.79       275

# %%
# Calculating for CART
cart_pred = cart_model.predict(X_test)

print('Performance Metrics for CART:\n')
print(accuracy_score(y_test, cart_pred).round(5), '\n')
print(confusion_matrix(y_test, cart_pred), '\n')
print(classification_report(y_test, cart_pred))
# Out:
# Performance Metrics for CART:
#
# 0.77455
#
# [[102  29]
#  [ 33 111]]
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       131
#            1       0.79      0.77      0.78       144
#
#     accuracy                           0.77       275
#    macro avg       0.77      0.77      0.77       275
# weighted avg       0.78      0.77      0.77       275

# %%
# Calculating for GNB
gnb_pred = log_model.predict(X_test)

print('Performance Metrics for GNB:\n')
print(accuracy_score(y_test, gnb_pred).round(5), '\n')
print(confusion_matrix(y_test, gnb_pred), '\n')
print(classification_report(y_test, gnb_pred))
# Out:
# Performance Metrics for GNB:
#
# 0.79273
#
# [[102  29]
#  [ 28 116]]
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78       131
#            1       0.80      0.81      0.80       144
#
#     accuracy                           0.79       275
#    macro avg       0.79      0.79      0.79       275
# weighted avg       0.79      0.79      0.79       275

# %%
# Calculating for Support Vector Machine
svm_pred = svm_model.predict(X_test)

print('Performance Metrics for SVM:\n')
print(accuracy_score(y_test, svm_pred).round(5), '\n')
print(confusion_matrix(y_test, svm_pred), '\n')
print(classification_report(y_test, svm_pred))
# Out:
# Performance Metrics for SVM:
#
# 0.80364
#
# [[100  31]
#  [ 23 121]]
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.79       131
#            1       0.80      0.84      0.82       144
#
#     accuracy                           0.80       275
#    macro avg       0.80      0.80      0.80       275
# weighted avg       0.80      0.80      0.80       275

# %%
# Calculating for Random Forest Classifier
rfc_pred = rfc_model.predict(X_test)

print('Performance Metrics for RFC:\n')
print(accuracy_score(y_test, rfc_pred).round(5), '\n')
print(confusion_matrix(y_test, rfc_pred), '\n')
print(classification_report(y_test, rfc_pred))
# Out:
# Performance Metrics for RFC:
#
# 0.89818
#
# [[119  12]
#  [ 16 128]]
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89       131
#            1       0.91      0.89      0.90       144
#
#     accuracy                           0.90       275
#    macro avg       0.90      0.90      0.90       275
# weighted avg       0.90      0.90      0.90       275

# %%
# Obtain the top features from the classification results

# Logistic Regression

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(log_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# Creatinine (umol/L)                       1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# C-Reactive Protein                        1
# ALT                                       1
# Monocytes (/L)                            1
# Neutrophils (/L)                          1
# Total Protein (g/L)                       2
# S.G.                                      3
# pH                                        4
# Potassium (mmol/L)                        5
# Chloride (mmol/L)                         6
# Urea (mmol/L)                             7
# 25-hydroxy Vitamin D (nmol/L)             8
# White Cell Count (/L)                     9
# Globulin (g/L)                           10
# Haemoglobin (g/L)                        11
# Uric Acid (mmol/L)                       12
# Glucose (mmol/L)                         13
# Total Bilirubin (µmol/L)                 14
# Vitamin B12 (pmol/L)                     15
# Phosphate (mmol/L)                       16
# HDL Cholesterol (mmol/L)                 17
# Triglyceride (mmol/L)                    18
# Albumin/Globulin ratio                   19
# MCV (fL)                                 20
# Platelets (/L)                           21
# GGT                                      22
# AST                                      23
# Free Tri-iodothyronine (FT3) (pmol/L)    24
# Total Cholesterol (mmol/L)               25
# Alkaline Phosphatase (U/L)               26
# Total Cholesterol/HDL Ratio              27
# HbA1c                                    28
# MCH (pg)                                 29
# Albumin (g/L)                            30
# MCHC (g/L)                               31
# RDW (%)                                  32
# LDL Cholesterol (mmol/L)                 33
# Lymphocytes (/L)                         34
# Thyroid Stimulating Hormone (mIU/L)      35
# Calcium (mmol/L)                         36
# Corrected Calcium (mmol/L)               37

# %%
# Linear Discriminant Analysis

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(lda_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# MCH (pg)                                  1
# Serum Homocysteine (µmol/L)               1
# Total Protein (g/L)                       1
# Albumin (g/L)                             1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# C-Reactive Protein                        1
# Globulin (g/L)                            1
# MCHC (g/L)                                1
# Monocytes (/L)                            1
# ALT                                       2
# Serum Folate (nmol/L)                     3
# Sodium (mmol/L)                           4
# GGT                                       5
# Total Bilirubin (µmol/L)                  6
# Total Cholesterol (mmol/L)                7
# LDL Cholesterol (mmol/L)                  8
# Calcium (mmol/L)                          9
# Potassium (mmol/L)                       10
# Glucose (mmol/L)                         11
# Alkaline Phosphatase (U/L)               12
# S.G.                                     13
# Neutrophils (/L)                         14
# Platelets (/L)                           15
# 25-hydroxy Vitamin D (nmol/L)            16
# Vitamin B12 (pmol/L)                     17
# pH                                       18
# Haemoglobin (g/L)                        19
# Total Cholesterol/HDL Ratio              20
# HDL Cholesterol (mmol/L)                 21
# White Cell Count (/L)                    22
# HbA1c                                    23
# Thyroid Stimulating Hormone (mIU/L)      24
# Uric Acid (mmol/L)                       25
# Lymphocytes (/L)                         26
# Corrected Calcium (mmol/L)               27
# Albumin/Globulin ratio                   28
# MCV (fL)                                 29
# Urea (mmol/L)                            30
# Free Tri-iodothyronine (FT3) (pmol/L)    31
# Chloride (mmol/L)                        32
# RDW (%)                                  33
# Triglyceride (mmol/L)                    34
# Phosphate (mmol/L)                       35
# Creatinine (umol/L)                      36
# AST                                      37

# %%
# Classification and Regression Trees

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(cart_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Total Cholesterol/HDL Ratio               1
# C-Reactive Protein                        1
# Serum Homocysteine (µmol/L)               1
# ALT                                       1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# Calcium (mmol/L)                          1
# Urea (mmol/L)                             1
# White Cell Count (/L)                     1
# Glucose (mmol/L)                          1
# Potassium (mmol/L)                        2
# MCHC (g/L)                                3
# Phosphate (mmol/L)                        4
# Vitamin B12 (pmol/L)                      5
# Total Cholesterol (mmol/L)                6
# Monocytes (/L)                            7
# Platelets (/L)                            8
# Creatinine (umol/L)                       9
# Haemoglobin (g/L)                        10
# 25-hydroxy Vitamin D (nmol/L)            11
# RDW (%)                                  12
# Lymphocytes (/L)                         13
# MCV (fL)                                 14
# Serum Folate (nmol/L)                    15
# Chloride (mmol/L)                        16
# Corrected Calcium (mmol/L)               17
# Globulin (g/L)                           18
# GGT                                      19
# Uric Acid (mmol/L)                       20
# Albumin/Globulin ratio                   21
# Total Protein (g/L)                      22
# Albumin (g/L)                            23
# AST                                      24
# Neutrophils (/L)                         25
# Total Bilirubin (µmol/L)                 26
# Triglyceride (mmol/L)                    27
# pH                                       28
# LDL Cholesterol (mmol/L)                 29
# MCH (pg)                                 30
# HDL Cholesterol (mmol/L)                 31
# S.G.                                     32
# Thyroid Stimulating Hormone (mIU/L)      33
# Alkaline Phosphatase (U/L)               34
# Free Tri-iodothyronine (FT3) (pmol/L)    35
# HbA1c                                    36
# Sodium (mmol/L)                          37

# %%
# Support Vector Machines

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(svm_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# Creatinine (umol/L)                       1
# Globulin (g/L)                            1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# C-Reactive Protein                        1
# ALT                                       1
# Monocytes (/L)                            1
# Total Bilirubin (µmol/L)                  2
# White Cell Count (/L)                     3
# Potassium (mmol/L)                        4
# S.G.                                      5
# Neutrophils (/L)                          6
# pH                                        7
# Total Protein (g/L)                       8
# Chloride (mmol/L)                         9
# GGT                                      10
# Alkaline Phosphatase (U/L)               11
# Albumin/Globulin ratio                   12
# Vitamin B12 (pmol/L)                     13
# HbA1c                                    14
# Uric Acid (mmol/L)                       15
# 25-hydroxy Vitamin D (nmol/L)            16
# Triglyceride (mmol/L)                    17
# Glucose (mmol/L)                         18
# Urea (mmol/L)                            19
# HDL Cholesterol (mmol/L)                 20
# Platelets (/L)                           21
# RDW (%)                                  22
# LDL Cholesterol (mmol/L)                 23
# Phosphate (mmol/L)                       24
# MCHC (g/L)                               25
# Free Tri-iodothyronine (FT3) (pmol/L)    26
# Albumin (g/L)                            27
# Total Cholesterol (mmol/L)               28
# MCH (pg)                                 29
# MCV (fL)                                 30
# Corrected Calcium (mmol/L)               31
# Lymphocytes (/L)                         32
# Haemoglobin (g/L)                        33
# Thyroid Stimulating Hormone (mIU/L)      34
# Total Cholesterol/HDL Ratio              35
# AST                                      36
# Calcium (mmol/L)                         37

# %%
# Random Forest Classifier

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(rfc_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# C-Reactive Protein                        1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# ALT                                       1
# Creatinine (umol/L)                       1
# White Cell Count (/L)                     1
# Neutrophils (/L)                          1
# Triglyceride (mmol/L)                     1
# Free Tri-iodothyronine (FT3) (pmol/L)     2
# Potassium (mmol/L)                        3
# HbA1c                                     4
# Haemoglobin (g/L)                         5
# Sodium (mmol/L)                           6
# 25-hydroxy Vitamin D (nmol/L)             7
# HDL Cholesterol (mmol/L)                  8
# Monocytes (/L)                            9
# MCH (pg)                                 10
# Chloride (mmol/L)                        11
# Total Cholesterol (mmol/L)               12
# Urea (mmol/L)                            13
# S.G.                                     14
# Glucose (mmol/L)                         15
# MCV (fL)                                 16
# Globulin (g/L)                           17
# MCHC (g/L)                               18
# pH                                       19
# Total Cholesterol/HDL Ratio              20
# Phosphate (mmol/L)                       21
# RDW (%)                                  22
# Vitamin B12 (pmol/L)                     23
# Calcium (mmol/L)                         24
# Albumin (g/L)                            25
# LDL Cholesterol (mmol/L)                 26
# GGT                                      27
# Uric Acid (mmol/L)                       28
# Total Bilirubin (µmol/L)                 29
# Total Protein (g/L)                      30
# AST                                      31
# Thyroid Stimulating Hormone (mIU/L)      32
# Platelets (/L)                           33
# Alkaline Phosphatase (U/L)               34
# Corrected Calcium (mmol/L)               35
# Lymphocytes (/L)                         36
# Albumin/Globulin ratio                   37

# %%
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedStratifiedKFold
import matplotlib.pyplot as plt

# get a list of models to evaluate
def get_models():
    models = dict()
    # Logistic Regression
    rfe = RFE(log_model, 10)
    model = DecisionTreeClassifier()
    models['LOG'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Linear Discriminant Analysis
    rfe = RFE(lda_model, 10)
    model = DecisionTreeClassifier()
    models['LDA'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Classification & Regression Trees
    rfe = RFE(cart_model, 10)
    model = DecisionTreeClassifier()
    models['CART'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Support Vector Machines
    rfe = RFE(svm_model, 10)
    model = DecisionTreeClassifier()
    models['SVM'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Random Forest Classifier
    rfe = RFE(rfc_model, 10)
    model = DecisionTreeClassifier()
    models['RFC'] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    return scores

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X_train, y_train)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# >LOG 0.768 (0.074)
# >LDA 0.778 (0.069)
# >CART 0.776 (0.062)
# >SVM 0.783 (0.080)
# >RFC 0.789 (0.064)

# %%
# CROSS-VALIDATION:

# %%
# Logistic Regression

log_model = LogisticRegression()
log_model.fit(X, y)
scores = cross_val_score(log_model, X, y, cv=5)
print("Logistic Regression: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Linear Discriminant Analysis

lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X, y)
scores = cross_val_score(lda_model, X, y, cv=5)
print("Linear Discriminant Analysis: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# K-Nearest Neigbors

knn_model = KNeighborsClassifier()
knn_model.fit(X, y)
scores = cross_val_score(knn_model, X, y, cv=5)
print("K-Nearest Neighbors: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Classification and Regression Trees

cart_model = DecisionTreeClassifier()
cart_model.fit(X, y)
scores = cross_val_score(cart_model, X, y, cv=5)
print("Classification and Regression Trees: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Gaussian Naive Bayes

gnb_model = GaussianNB()
gnb_model.fit(X, y)
scores = cross_val_score(gnb_model, X, y, cv=5)
print("Gaussian Naive Bayes: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Support Vector Machines

svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X, y)
scores = cross_val_score(svm_model, X, y, cv=5)
print("Support Vector Machines: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))

# Random Forest Classifier

rfc_model = RandomForestClassifier()
rfc_model.fit(X, y)
scores = cross_val_score(rfc_model, X, y, cv=5)
print("Random Forest Classifier: %0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))
# Out:
# Logistic Regression: 0.789 accuracy with a standard deviation of 0.040
# Linear Discriminant Analysis: 0.805 accuracy with a standard deviation of 0.030
# K-Nearest Neighbors: 0.789 accuracy with a standard deviation of 0.043
# Classification and Regression Trees: 0.792 accuracy with a standard deviation of 0.031
# Gaussian Naive Bayes: 0.741 accuracy with a standard deviation of 0.040
# Support Vector Machines: 0.803 accuracy with a standard deviation of 0.035
# Random Forest Classifier: 0.932 accuracy with a standard deviation of 0.016

# %%
# Producing Cross-Validation Classification Reports for each Algorithm

# %%
# Logistic Regression
scores = cross_val_score(log_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76        69
#            1       0.76      0.74      0.75        69
#
#     accuracy                           0.75       138
#    macro avg       0.75      0.75      0.75       138
# weighted avg       0.75      0.75      0.75       138
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74        68
#            1       0.72      0.84      0.78        69
#
#     accuracy                           0.76       137
#    macro avg       0.77      0.76      0.76       137
# weighted avg       0.77      0.76      0.76       137
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.63      0.72        68
#            1       0.71      0.88      0.79        69
#
#     accuracy                           0.76       137
#    macro avg       0.78      0.76      0.75       137
# weighted avg       0.78      0.76      0.76       137
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        69
#            1       0.85      0.85      0.85        68
#
#     accuracy                           0.85       137
#    macro avg       0.85      0.85      0.85       137
# weighted avg       0.85      0.85      0.85       137
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.72      0.80        69
#            1       0.77      0.91      0.83        68
#
#     accuracy                           0.82       137
#    macro avg       0.83      0.82      0.82       137
# weighted avg       0.83      0.82      0.82       137
#
# [0.75362319 0.75912409 0.75912409 0.8540146  0.81751825]

# %%
# Linear Discriminant Analysis
scores = cross_val_score(lda_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77        69
#            1       0.76      0.81      0.78        69
#
#     accuracy                           0.78       138
#    macro avg       0.78      0.78      0.78       138
# weighted avg       0.78      0.78      0.78       138
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.72      0.79        68
#            1       0.77      0.90      0.83        69
#
#     accuracy                           0.81       137
#    macro avg       0.82      0.81      0.81       137
# weighted avg       0.82      0.81      0.81       137
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.62      0.72        68
#            1       0.71      0.91      0.80        69
#
#     accuracy                           0.77       137
#    macro avg       0.79      0.77      0.76       137
# weighted avg       0.79      0.77      0.76       137
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        69
#            1       0.83      0.87      0.85        68
#
#     accuracy                           0.85       137
#    macro avg       0.85      0.85      0.85       137
# weighted avg       0.85      0.85      0.85       137
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.72      0.81        69
#            1       0.77      0.93      0.84        68
#
#     accuracy                           0.82       137
#    macro avg       0.84      0.83      0.82       137
# weighted avg       0.84      0.82      0.82       137
#
# [0.77536232 0.81021898 0.76642336 0.84671533 0.82481752]

# %%
# K-Nearest Neigbors
knn_model = KNeighborsClassifier()
knn_model.fit(X, y)
scores = cross_val_score(knn_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        69
#            1       0.72      0.91      0.80        69
#
#     accuracy                           0.78       138
#    macro avg       0.80      0.78      0.77       138
# weighted avg       0.80      0.78      0.77       138
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.60      0.75        68
#            1       0.72      0.99      0.83        69
#
#     accuracy                           0.80       137
#    macro avg       0.85      0.79      0.79       137
# weighted avg       0.85      0.80      0.79       137
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.49      0.65        68
#            1       0.66      1.00      0.80        69
#
#     accuracy                           0.74       137
#    macro avg       0.83      0.74      0.73       137
# weighted avg       0.83      0.74      0.73       137
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85        69
#            1       0.79      1.00      0.88        68
#
#     accuracy                           0.87       137
#    macro avg       0.90      0.87      0.87       137
# weighted avg       0.90      0.87      0.87       137
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.52      0.69        69
#            1       0.67      1.00      0.80        68
#
#     accuracy                           0.76       137
#    macro avg       0.84      0.76      0.75       137
# weighted avg       0.84      0.76      0.74       137
#
# [0.77536232 0.79562044 0.74452555 0.86861314 0.75912409]

# %%
# Classification and Regression Trees
cart_model = DecisionTreeClassifier()
cart_model.fit(X, y)
scores = cross_val_score(cart_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.72        69
#            1       0.73      0.65      0.69        69
#
#     accuracy                           0.70       138
#    macro avg       0.71      0.70      0.70       138
# weighted avg       0.71      0.70      0.70       138
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.75        68
#            1       0.73      0.88      0.80        69
#
#     accuracy                           0.78       137
#    macro avg       0.79      0.78      0.78       137
# weighted avg       0.79      0.78      0.78       137
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.66      0.74        68
#            1       0.73      0.88      0.80        69
#
#     accuracy                           0.77       137
#    macro avg       0.79      0.77      0.77       137
# weighted avg       0.79      0.77      0.77       137
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83        69
#            1       0.80      0.93      0.86        68
#
#     accuracy                           0.85       137
#    macro avg       0.86      0.85      0.85       137
# weighted avg       0.86      0.85      0.85       137
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85        69
#            1       0.84      0.85      0.85        68
#
#     accuracy                           0.85       137
#    macro avg       0.85      0.85      0.85       137
# weighted avg       0.85      0.85      0.85       137
#
# [0.70289855 0.7810219  0.77372263 0.84671533 0.84671533]

# %%
# Gaussian Naive Bayes
gnb_model = GaussianNB()
gnb_model.fit(X, y)
scores = cross_val_score(gnb_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.87      0.74        69
#            1       0.80      0.52      0.63        69
#
#     accuracy                           0.70       138
#    macro avg       0.72      0.70      0.69       138
# weighted avg       0.72      0.70      0.69       138
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.77        68
#            1       0.78      0.72      0.75        69
#
#     accuracy                           0.76       137
#    macro avg       0.76      0.76      0.76       137
# weighted avg       0.76      0.76      0.76       137
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.72      0.71        68
#            1       0.71      0.68      0.70        69
#
#     accuracy                           0.70       137
#    macro avg       0.70      0.70      0.70       137
# weighted avg       0.70      0.70      0.70       137
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.87      0.77        69
#            1       0.82      0.62      0.71        68
#
#     accuracy                           0.74       137
#    macro avg       0.76      0.74      0.74       137
# weighted avg       0.76      0.74      0.74       137
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81        69
#            1       0.81      0.79      0.80        68
#
#     accuracy                           0.80       137
#    macro avg       0.80      0.80      0.80       137
# weighted avg       0.80      0.80      0.80       137
#
# [0.69565217 0.75912409 0.70072993 0.74452555 0.80291971]

# %%
# Support Vector Machines
svm_model = SVC(kernel='linear', gamma = 'auto')
svm_model.fit(X, y)
scores = cross_val_score(svm_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79        69
#            1       0.79      0.81      0.80        69
#
#     accuracy                           0.80       138
#    macro avg       0.80      0.80      0.80       138
# weighted avg       0.80      0.80      0.80       138
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.71      0.78        68
#            1       0.76      0.90      0.82        69
#
#     accuracy                           0.80       137
#    macro avg       0.81      0.80      0.80       137
# weighted avg       0.81      0.80      0.80       137
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.59      0.70        68
#            1       0.69      0.90      0.78        69
#
#     accuracy                           0.74       137
#    macro avg       0.77      0.74      0.74       137
# weighted avg       0.77      0.74      0.74       137
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85        69
#            1       0.83      0.88      0.86        68
#
#     accuracy                           0.85       137
#    macro avg       0.86      0.85      0.85       137
# weighted avg       0.86      0.85      0.85       137
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.70      0.79        69
#            1       0.75      0.94      0.84        68
#
#     accuracy                           0.82       137
#    macro avg       0.84      0.82      0.81       137
# weighted avg       0.84      0.82      0.81       137
#
# [0.79710145 0.80291971 0.74452555 0.8540146  0.81751825]

# %%
# Random Forest Classifier
rfc_model = RandomForestClassifier()
rfc_model.fit(X, y)
scores = cross_val_score(rfc_model, X, y, cv=5, scoring=make_scorer(classification_report_with_accuracy_score))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92        69
#            1       0.98      0.84      0.91        69
#
#     accuracy                           0.91       138
#    macro avg       0.92      0.91      0.91       138
# weighted avg       0.92      0.91      0.91       138
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        68
#            1       0.94      0.99      0.96        69
#
#     accuracy                           0.96       137
#    macro avg       0.96      0.96      0.96       137
# weighted avg       0.96      0.96      0.96       137
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90        68
#            1       0.86      0.97      0.91        69
#
#     accuracy                           0.91       137
#    macro avg       0.91      0.90      0.90       137
# weighted avg       0.91      0.91      0.90       137
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        69
#            1       0.92      0.97      0.94        68
#
#     accuracy                           0.94       137
#    macro avg       0.94      0.94      0.94       137
# weighted avg       0.94      0.94      0.94       137
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        69
#            1       0.87      1.00      0.93        68
#
#     accuracy                           0.93       137
#    macro avg       0.94      0.93      0.93       137
# weighted avg       0.94      0.93      0.93       137
#
# [0.91304348 0.96350365 0.90510949 0.94160584 0.9270073 ]

# %%
# Logistic Regression

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(log_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# Creatinine (umol/L)                       1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# C-Reactive Protein                        1
# ALT                                       1
# Monocytes (/L)                            1
# Neutrophils (/L)                          1
# Total Protein (g/L)                       2
# S.G.                                      3
# pH                                        4
# Potassium (mmol/L)                        5
# Chloride (mmol/L)                         6
# Urea (mmol/L)                             7
# 25-hydroxy Vitamin D (nmol/L)             8
# White Cell Count (/L)                     9
# Globulin (g/L)                           10
# Haemoglobin (g/L)                        11
# Uric Acid (mmol/L)                       12
# Glucose (mmol/L)                         13
# Total Bilirubin (µmol/L)                 14
# Vitamin B12 (pmol/L)                     15
# Phosphate (mmol/L)                       16
# HDL Cholesterol (mmol/L)                 17
# Triglyceride (mmol/L)                    18
# Albumin/Globulin ratio                   19
# MCV (fL)                                 20
# Platelets (/L)                           21
# GGT                                      22
# AST                                      23
# Free Tri-iodothyronine (FT3) (pmol/L)    24
# Total Cholesterol (mmol/L)               25
# Alkaline Phosphatase (U/L)               26
# Total Cholesterol/HDL Ratio              27
# HbA1c                                    28
# MCH (pg)                                 29
# Albumin (g/L)                            30
# MCHC (g/L)                               31
# RDW (%)                                  32
# LDL Cholesterol (mmol/L)                 33
# Lymphocytes (/L)                         34
# Thyroid Stimulating Hormone (mIU/L)      35
# Calcium (mmol/L)                         36
# Corrected Calcium (mmol/L)               37

# %%
# Linear Discriminant Analysis

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(lda_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# MCH (pg)                                  1
# Serum Homocysteine (µmol/L)               1
# Total Protein (g/L)                       1
# Albumin (g/L)                             1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# C-Reactive Protein                        1
# Globulin (g/L)                            1
# MCHC (g/L)                                1
# Monocytes (/L)                            1
# ALT                                       2
# Serum Folate (nmol/L)                     3
# Sodium (mmol/L)                           4
# GGT                                       5
# Total Bilirubin (µmol/L)                  6
# Total Cholesterol (mmol/L)                7
# LDL Cholesterol (mmol/L)                  8
# Calcium (mmol/L)                          9
# Potassium (mmol/L)                       10
# Glucose (mmol/L)                         11
# Alkaline Phosphatase (U/L)               12
# S.G.                                     13
# Neutrophils (/L)                         14
# Platelets (/L)                           15
# 25-hydroxy Vitamin D (nmol/L)            16
# Vitamin B12 (pmol/L)                     17
# pH                                       18
# Haemoglobin (g/L)                        19
# Total Cholesterol/HDL Ratio              20
# HDL Cholesterol (mmol/L)                 21
# White Cell Count (/L)                    22
# HbA1c                                    23
# Thyroid Stimulating Hormone (mIU/L)      24
# Uric Acid (mmol/L)                       25
# Lymphocytes (/L)                         26
# Corrected Calcium (mmol/L)               27
# Albumin/Globulin ratio                   28
# MCV (fL)                                 29
# Urea (mmol/L)                            30
# Free Tri-iodothyronine (FT3) (pmol/L)    31
# Chloride (mmol/L)                        32
# RDW (%)                                  33
# Triglyceride (mmol/L)                    34
# Phosphate (mmol/L)                       35
# Creatinine (umol/L)                      36
# AST                                      37

# %%
# Classification and Regression Trees

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(cart_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Total Cholesterol/HDL Ratio               1
# C-Reactive Protein                        1
# Serum Homocysteine (µmol/L)               1
# ALT                                       1
# Urea (mmol/L)                             1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# Potassium (mmol/L)                        1
# Glucose (mmol/L)                          1
# White Cell Count (/L)                     1
# Vitamin B12 (pmol/L)                      2
# Thyroid Stimulating Hormone (mIU/L)       3
# Calcium (mmol/L)                          4
# Total Cholesterol (mmol/L)                5
# MCHC (g/L)                                6
# Creatinine (umol/L)                       7
# Haemoglobin (g/L)                         8
# Phosphate (mmol/L)                        9
# 25-hydroxy Vitamin D (nmol/L)            10
# Serum Folate (nmol/L)                    11
# RDW (%)                                  12
# Platelets (/L)                           13
# Chloride (mmol/L)                        14
# MCV (fL)                                 15
# Albumin/Globulin ratio                   16
# Globulin (g/L)                           17
# Total Protein (g/L)                      18
# Total Bilirubin (µmol/L)                 19
# Triglyceride (mmol/L)                    20
# Alkaline Phosphatase (U/L)               21
# AST                                      22
# Corrected Calcium (mmol/L)               23
# Uric Acid (mmol/L)                       24
# S.G.                                     25
# pH                                       26
# Monocytes (/L)                           27
# MCH (pg)                                 28
# Neutrophils (/L)                         29
# Lymphocytes (/L)                         30
# HDL Cholesterol (mmol/L)                 31
# LDL Cholesterol (mmol/L)                 32
# Free Tri-iodothyronine (FT3) (pmol/L)    33
# GGT                                      34
# HbA1c                                    35
# Albumin (g/L)                            36
# Sodium (mmol/L)                          37

# %%
# Support Vector Machines

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(svm_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Sodium (mmol/L)                           1
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# Creatinine (umol/L)                       1
# Globulin (g/L)                            1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# C-Reactive Protein                        1
# ALT                                       1
# Monocytes (/L)                            1
# Total Bilirubin (µmol/L)                  2
# White Cell Count (/L)                     3
# Potassium (mmol/L)                        4
# S.G.                                      5
# Neutrophils (/L)                          6
# pH                                        7
# Total Protein (g/L)                       8
# Chloride (mmol/L)                         9
# GGT                                      10
# Alkaline Phosphatase (U/L)               11
# Albumin/Globulin ratio                   12
# Vitamin B12 (pmol/L)                     13
# HbA1c                                    14
# Uric Acid (mmol/L)                       15
# 25-hydroxy Vitamin D (nmol/L)            16
# Triglyceride (mmol/L)                    17
# Glucose (mmol/L)                         18
# Urea (mmol/L)                            19
# HDL Cholesterol (mmol/L)                 20
# Platelets (/L)                           21
# RDW (%)                                  22
# LDL Cholesterol (mmol/L)                 23
# Phosphate (mmol/L)                       24
# MCHC (g/L)                               25
# Free Tri-iodothyronine (FT3) (pmol/L)    26
# Albumin (g/L)                            27
# Total Cholesterol (mmol/L)               28
# MCH (pg)                                 29
# MCV (fL)                                 30
# Corrected Calcium (mmol/L)               31
# Lymphocytes (/L)                         32
# Haemoglobin (g/L)                        33
# Thyroid Stimulating Hormone (mIU/L)      34
# Total Cholesterol/HDL Ratio              35
# AST                                      36
# Calcium (mmol/L)                         37

# %%
# Random Forest Classifier

# Create the Recursive Feature Elimination (RFE) model and select 10 attributes
rfe = RFE(rfc_model, 10)
rfe = rfe.fit(X_train, y_train)

# Summarise the selection of the attributes
# pd.DataFrame(rfe.support_,index=X_old.columns,columns=['Rank'])
rfe_df = pd.DataFrame(rfe.ranking_,index=X_old.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
rfe_df.index = rfe_df.index.map(featureName_mapping)
rfe_df
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
#                                        Rank
# Serum Folate (nmol/L)                     1
# Serum Homocysteine (µmol/L)               1
# C-Reactive Protein                        1
# RBC (/L)                                  1
# PCV (L/L)                                 1
# ALT                                       1
# Creatinine (umol/L)                       1
# White Cell Count (/L)                     1
# Neutrophils (/L)                          1
# Free Tri-iodothyronine (FT3) (pmol/L)     1
# Monocytes (/L)                            2
# 25-hydroxy Vitamin D (nmol/L)             3
# HbA1c                                     4
# MCH (pg)                                  5
# Triglyceride (mmol/L)                     6
# Calcium (mmol/L)                          7
# Sodium (mmol/L)                           8
# MCV (fL)                                  9
# Glucose (mmol/L)                         10
# Total Protein (g/L)                      11
# Haemoglobin (g/L)                        12
# S.G.                                     13
# Chloride (mmol/L)                        14
# pH                                       15
# Potassium (mmol/L)                       16
# Albumin (g/L)                            17
# HDL Cholesterol (mmol/L)                 18
# Uric Acid (mmol/L)                       19
# LDL Cholesterol (mmol/L)                 20
# Vitamin B12 (pmol/L)                     21
# Urea (mmol/L)                            22
# Total Cholesterol/HDL Ratio              23
# MCHC (g/L)                               24
# Alkaline Phosphatase (U/L)               25
# Phosphate (mmol/L)                       26
# Globulin (g/L)                           27
# Total Cholesterol (mmol/L)               28
# Total Bilirubin (µmol/L)                 29
# RDW (%)                                  30
# GGT                                      31
# Thyroid Stimulating Hormone (mIU/L)      32
# Platelets (/L)                           33
# AST                                      34
# Lymphocytes (/L)                         35
# Albumin/Globulin ratio                   36
# Corrected Calcium (mmol/L)               37

# %%
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedStratifiedKFold
import matplotlib.pyplot as plt

# get a list of models to evaluate
def get_models():
    models = dict()
    # Logistic Regression
    rfe = RFE(log_model, 10)
    model = DecisionTreeClassifier()
    models['LOG'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Linear Discriminant Analysis
    rfe = RFE(lda_model, 10)
    model = DecisionTreeClassifier()
    models['LDA'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Classification & Regression Trees
    rfe = RFE(cart_model, 10)
    model = DecisionTreeClassifier()
    models['CART'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Support Vector Machines
    rfe = RFE(svm_model, 10)
    model = DecisionTreeClassifier()
    models['SVM'] = Pipeline(steps=[('s',rfe),('m',model)])
    # Random Forest Classifier
    rfe = RFE(rfc_model, 10)
    model = DecisionTreeClassifier()
    models['RFC'] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    return scores

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X_train, y_train)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# C:\Users\shahi\anaconda3\envs\FYP\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# >LOG 0.766 (0.064)
# >LDA 0.774 (0.056)
# >CART 0.778 (0.068)
# >SVM 0.774 (0.079)
# >RFC 0.794 (0.069)
