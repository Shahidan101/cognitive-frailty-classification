# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from parse import preprocess

# %%
# Pre-parse the dataset
data = preprocess("rawfile_blood.csv")
# Out:
# robust          368
# prefrail_mci    268
# prefrail        250
# mci             142
# frail_mci        86
# frail             9
# Name: condition, dtype: int64
#
# ####################################################################
# Number of Rows of Dataframe:
# 1123
# Number of Columns of Dataframe:
# 59
#
# ####################################################################
# Threshold for number of NULLs in a column: 0.1095
# Number of Columns before Parsing for Too Many NULLs in a column:
# 59
# Number of Columns after Parsing for Too Many NULLs in a column:
# 51
#
# Columns Removed:
# B1_b5
# B4_a1
# B4_a3
# B4_a4
# B4_a6
# B4_b1
# B4_b3
# B5_a1
#
# ####################################################################
# Number of Columns after dropping A1_2, B1_b4, B2_c3, B4_b2 for inconsistent data types:
# 47
#
# ####################################################################
# Number of Rows before Parsing NULLs in data:
# 1123
# ...

# %%
data.describe()
# Out:
#               A1_1         A2_1         A3_1         B1_a        B1_a1  \
# count  1015.000000  1015.000000  1015.000000  1015.000000  1015.000000
# mean    407.066010    17.761576    52.306079   137.189163     4.716271
# std     195.315621     6.316309    19.387415    17.139516     0.545034
# min     104.000000     1.000000     4.070000    75.000000     0.004720
# 25%     280.000000    14.000000    39.100000   128.000000     4.400000
# 50%     362.000000    17.000000    51.200000   136.000000     4.700000
# 75%     474.500000    20.000000    63.450000   146.000000     5.010000
# max    1476.000000    95.000000   159.000000   413.000000     7.850000
#
#              B1_a2        B1_a3        B1_a4        B1_a5        B1_a6  ...  \
# count  1015.000000  1015.000000  1015.000000  1015.000000  1015.000000  ...
# mean      0.415409    88.259113    29.145813   329.933990    13.846700  ...
# std       0.040204     6.883710     2.525690    12.189844     1.109919  ...
# ...

# %%
data.head()
# Out:
#       mtag condition  A1_1  A2_1  A3_1  B1_a  B1_a1  B1_a2  B1_a3  B1_a4  ...  \
# 0  ME02646     frail   196    24  46.5   121   3.93   0.37     95     31  ...
# 1  ME03109     frail   200    23  55.6   142   4.82   0.42     87     30  ...
# 2  ME06997     frail   441    20  76.8   105   4.54   0.41     90     30  ...
# 3  ME07149     frail   265    16  47.2   122   4.53   0.39     86     27  ...
# 4  ME07700     frail   425    14  31.3   124   4.44   0.38     85     28  ...
#
#    B2_d6  B2_d7  B2_d8  B2_d9   B3  B4_a2  B4_a5  B5_a2  B5_a3   B6
# 0      7     12     13      6  0.2    6.0  1.011   1.14    4.1  5.9
# 1      7     20     17     26  3.1    5.0  1.011   3.25    4.6  8.5
# 2      5     16     19     15  1.4    7.0  1.023   2.14    4.0  6.4
# 3      8     24     19     21  2.1    5.5  1.012   1.06    4.7  6.1
# 4      6     20     23     23  6.0    5.5  1.013   1.95    3.8  5.8
#
# [5 rows x 47 columns]

# %%
plt.rcParams['figure.figsize'] = [10, 5]

features = ['A1_1', 'A2_1', 'A3_1', 'B1_a', 'B1_a1', 'B1_a2',
       'B1_a3', 'B1_a4', 'B1_a5', 'B1_a6', 'B1_b', 'B1_b1', 'B1_b2', 'B1_b3',
       'B1_c', 'B1_d', 'B2_a1', 'B2_a2', 'B2_a3', 'B2_a4', 'B2_a5', 'B2_b1',
       'B2_b2', 'B2_b3', 'B2_c1', 'B2_c2', 'B2_c4', 'B2_c5', 'B2_c6', 'B2_c7',
       'B2_d1', 'B2_d2', 'B2_d3', 'B2_d4', 'B2_d5', 'B2_d6', 'B2_d7', 'B2_d8',
       'B2_d9', 'B3', 'B4_a2', 'B4_a5', 'B5_a2', 'B5_a3', 'B6']

ax = sns.histplot(x=features[0],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[0]))
# Out:
# Text(0.5, 1.0, 'Condition by A1_1')

# %%
ax = sns.histplot(x=features[1],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[1]))
# Out:
# Text(0.5, 1.0, 'Condition by A2_1')

# %%
ax = sns.histplot(x=features[2],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[2]))
# Out:
# Text(0.5, 1.0, 'Condition by A3_1')

# %%
ax = sns.histplot(x=features[3],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[3]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_a')

# %%
ax = sns.histplot(x=features[4],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[4]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_a1')

# %%
ax = sns.histplot(x=features[5],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[5]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_a2')

# %%
ax = sns.histplot(x=features[6],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[6]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_a3')

# %%
ax = sns.histplot(x=features[7],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[7]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_a4')

# %%
ax = sns.histplot(x=features[8],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[8]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_a5')

# %%
ax = sns.histplot(x=features[9],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[9]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_a6')

# %%
ax = sns.histplot(x=features[10],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[10]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_b')

# %%
ax = sns.histplot(x=features[11],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[11]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_b1')

# %%
ax = sns.histplot(x=features[12],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[12]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_b2')

# %%
ax = sns.histplot(x=features[13],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[13]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_b3')

# %%
ax = sns.histplot(x=features[14],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[14]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_c')

# %%
ax = sns.histplot(x=features[15],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[15]))
# Out:
# Text(0.5, 1.0, 'Condition by B1_d')

# %%
ax = sns.histplot(x=features[16],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[16]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_a1')

# %%
ax = sns.histplot(x=features[17],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[17]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_a2')

# %%
ax = sns.histplot(x=features[18],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[18]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_a3')

# %%
ax = sns.histplot(x=features[19],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[19]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_a4')

# %%
ax = sns.histplot(x=features[20],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[20]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_a5')

# %%
ax = sns.histplot(x=features[21],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[21]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_b1')

# %%
ax = sns.histplot(x=features[22],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[22]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_b2')

# %%
ax = sns.histplot(x=features[23],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[23]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_b3')

# %%
ax = sns.histplot(x=features[24],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[24]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_c1')

# %%
ax = sns.histplot(x=features[25],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[25]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_c2')

# %%
ax = sns.histplot(x=features[26],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[26]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_c4')

# %%
ax = sns.histplot(x=features[27],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[27]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_c5')

# %%
ax = sns.histplot(x=features[28],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[28]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_c6')

# %%
ax = sns.histplot(x=features[29],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[29]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_c7')

# %%
ax = sns.histplot(x=features[30],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[30]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d1')

# %%
ax = sns.histplot(x=features[31],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[31]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d2')

# %%
ax = sns.histplot(x=features[32],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[32]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d3')

# %%
ax = sns.histplot(x=features[33],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[33]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d4')

# %%
ax = sns.histplot(x=features[34],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[34]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d5')

# %%
ax = sns.histplot(x=features[35],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[35]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d6')

# %%
ax = sns.histplot(x=features[36],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[36]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d7')

# %%
ax = sns.histplot(x=features[37],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[37]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d8')

# %%
ax = sns.histplot(x=features[38],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[38]))
# Out:
# Text(0.5, 1.0, 'Condition by B2_d9')

# %%
ax = sns.histplot(x=features[39],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[39]))
# Out:
# Text(0.5, 1.0, 'Condition by B3')

# %%
ax = sns.histplot(x=features[40],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[40]))
# Out:
# Text(0.5, 1.0, 'Condition by B4_a2')

# %%
ax = sns.histplot(x=features[41],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[41]))
# Out:
# Text(0.5, 1.0, 'Condition by B4_a5')

# %%
ax = sns.histplot(x=features[42],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[42]))
# Out:
# Text(0.5, 1.0, 'Condition by B5_a2')

# %%
ax = sns.histplot(x=features[43],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[43]))
# Out:
# Text(0.5, 1.0, 'Condition by B5_a3')

# %%
ax = sns.histplot(x=features[44],data=data,hue='condition',kde=True)
ax.set_title('Condition by {}'.format(features[44]))
# Out:
# Text(0.5, 1.0, 'Condition by B6')

# %%
data = pd.read_csv("rawfile_blood_parsed_encoded.csv")

features = ['A1_1', 'A2_1', 'A3_1', 'B1_a', 'B1_a1', 'B1_a2',
       'B1_a3', 'B1_a4', 'B1_a5', 'B1_a6', 'B1_b', 'B1_b1', 'B1_b2', 'B1_b3',
       'B1_c', 'B1_d', 'B2_a1', 'B2_a2', 'B2_a3', 'B2_a4', 'B2_a5', 'B2_b1',
       'B2_b2', 'B2_b3', 'B2_c1', 'B2_c2', 'B2_c4', 'B2_c5', 'B2_c6', 'B2_c7',
       'B2_d1', 'B2_d2', 'B2_d3', 'B2_d4', 'B2_d5', 'B2_d6', 'B2_d7', 'B2_d8',
       'B2_d9', 'B3', 'B5_a2', 'B5_a3', 'B6']

ax = sns.countplot(x=features[0],hue='condition',data=data)
ax.set_title('Condition by {}'.format(features[0]))
ax.set_xlabel(features[0])
# Out:
# Text(0.5, 0, 'A1_1')

# %%
ax = sns.countplot(x=features[1],hue='condition',data=data)
ax.set_title('Condition by {}'.format(features[1]))
ax.set_xlabel(features[1])
# Out:
# Text(0.5, 0, 'A2_1')

# %%
ax = sns.countplot(x=features[2],hue='condition',data=data)
ax.set_title('Condition by {}'.format(features[2]))
ax.set_xlabel(features[2])
# Out:
# Text(0.5, 0, 'A3_1')
